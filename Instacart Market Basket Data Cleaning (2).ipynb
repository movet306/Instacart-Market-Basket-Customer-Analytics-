# %%
import pandas as pd
orders = pd.read_csv("orders.csv")

# %%
print(orders.info()) 
print(orders.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3421083 entries, 0 to 3421082
# Data columns (total 7 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   eval_set                object
#  3   order_number            int64
#  4   order_dow               int64
#  5   order_hour_of_day       int64
#  6   days_since_prior_order  float64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 182.7+ MB
# None
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
print(orders.duplicated().sum())
# Out:
# 0

# %%
print(orders['order_id'].is_unique)
# Out:
# True

# %%
print(orders['eval_set'].value_counts())
print(orders['order_dow'].unique())
print(orders['order_hour_of_day'].unique())
# Out:
# eval_set
# prior    3214874
# train     131209
# test       75000
# Name: count, dtype: int64
# [2 3 4 1 5 0 6]
# [ 8  7 12 15  9 14 16 11 10 19 18 17 13 20  0 21 22  5 23  4  6  1  2  3]

# %%
orders.to_csv("cleaned_orders.csv", index=False)

# %%
import pandas as pd
products= pd.read_csv("products.csv")

# %%
print(orders.info()) 
print(products.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3421083 entries, 0 to 3421082
# Data columns (total 7 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   eval_set                object
#  3   order_number            int64
#  4   order_dow               int64
#  5   order_hour_of_day       int64
#  6   days_since_prior_order  float64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 182.7+ MB
# None
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13

# %%
print(products.shape)
# Out:
# (49688, 4)

# %%
print(products.isnull().sum())
# Out:
# product_id       0
# product_name     0
# aisle_id         0
# department_id    0
# dtype: int64

# %%
print(products.duplicated().sum())
# Out:
# 0

# %%
print(products['product_id'].is_unique)
# Out:
# True

# %%
print(products['aisle_id'].unique()[:10])        
print(products['department_id'].unique()[:10])
# Out:
# [ 61 104  94  38   5  11  98 116 120 115]
# [19 13  7  1 11 16 17 18 12  9]

# %%
print(products[products['product_name'].isnull() | (products['product_name'] == '')])
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, aisle_id, department_id]
# Index: []

# %%
products.to_csv("cleaned_products.csv", index=False)

# %%
prior = pd.read_csv("order_products__prior.csv") 
print(prior.info())
print(prior.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32434489 entries, 0 to 32434488
# Data columns (total 4 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   order_id           int64
#  1   product_id         int64
#  2   add_to_cart_order  int64
#  3   reordered          int64
# dtypes: int64(4)
# memory usage: 989.8 MB
# None
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
print(prior.isnull().sum())
# Out:
# order_id             0
# product_id           0
# add_to_cart_order    0
# reordered            0
# dtype: int64

# %%
print(prior.duplicated().sum())
# Out:
# 0

# %%
products = pd.read_csv("cleaned_products.csv")
orders = pd.read_csv("cleaned_orders.csv")

print(prior[~prior['product_id'].isin(products['product_id'])])
print(prior[~prior['order_id'].isin(orders['order_id'])])
# Out:
# Empty DataFrame
# Columns: [order_id, product_id, add_to_cart_order, reordered]
# Index: []
# Empty DataFrame
# Columns: [order_id, product_id, add_to_cart_order, reordered]
# Index: []

# %%
print(prior['reordered'].unique())
# Out:
# [1 0]

# %%
prior.to_csv("cleaned_order_products_prior.csv", index=False)

# %%
train = pd.read_csv("order_products__train.csv")
print(train.info())
print(train.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1384617 entries, 0 to 1384616
# Data columns (total 4 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   order_id           1384617 non-null  int64
#  1   product_id         1384617 non-null  int64
#  2   add_to_cart_order  1384617 non-null  int64
#  3   reordered          1384617 non-null  int64
# dtypes: int64(4)
# memory usage: 42.3 MB
# None
#    order_id  product_id  add_to_cart_order  reordered
# 0         1       49302                  1          1
# 1         1       11109                  2          1
# 2         1       10246                  3          0
# 3         1       49683                  4          0
# 4         1       43633                  5          1

# %%
print(train.isnull().sum())
# Out:
# order_id             0
# product_id           0
# add_to_cart_order    0
# reordered            0
# dtype: int64

# %%
print(train.duplicated().sum())
# Out:
# 0

# %%
products = pd.read_csv("cleaned_products.csv")
orders = pd.read_csv("cleaned_orders.csv")

print(train[~train['product_id'].isin(products['product_id'])])
print(train[~train['order_id'].isin(orders['order_id'])])
# Out:
# Empty DataFrame
# Columns: [order_id, product_id, add_to_cart_order, reordered]
# Index: []
# Empty DataFrame
# Columns: [order_id, product_id, add_to_cart_order, reordered]
# Index: []

# %%
print(train['reordered'].unique())
# Out:
# [1 0]

# %%
train.to_csv("cleaned_order_products_train.csv", index=False)

# %%
departments = pd.read_csv("departments.csv")
print(departments.info())
print(departments.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   department_id  21 non-null     int64
#  1   department     21 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 468.0+ bytes
# None
#    department_id department
# 0              1     frozen
# 1              2      other
# 2              3     bakery
# 3              4    produce
# 4              5    alcohol

# %%
print(departments.isnull().sum())
# Out:
# department_id    0
# department       0
# dtype: int64

# %%
print(departments.duplicated().sum())
# Out:
# 0

# %%
print(departments.duplicated().sum())
# Out:
# 0

# %%
print(departments['department_id'].is_unique)
# Out:
# True

# %%
print(departments[departments['department'].isnull() | (departments['department'] == '')])
# Out:
# Empty DataFrame
# Columns: [department_id, department]
# Index: []

# %%
departments.to_csv("cleaned_departments.csv", index=False)

# %%
aisles = pd.read_csv("aisles.csv")
print(aisles.info())
print(aisles.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   aisle_id  134 non-null    int64
#  1   aisle     134 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB
# None
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation

# %%
print(aisles.isnull().sum())
# Out:
# aisle_id    0
# aisle       0
# dtype: int64

# %%
print(aisles.duplicated().sum())
# Out:
# 0

# %%
print(aisles['aisle_id'].is_unique)
# Out:
# True

# %%
print(aisles[aisles['aisle'].isnull() | (aisles['aisle'] == '')])
# Out:
# Empty DataFrame
# Columns: [aisle_id, aisle]
# Index: []

# %%
aisles.to_csv("cleaned_aisles.csv", index=False)

# %%
import pandas as pd

df = pd.read_csv('products.csv')
print(df['product_name'].str.len().max())
print(df[df['product_name'].str.len() > 512])
# Out:
# 159
# Empty DataFrame
# Columns: [product_id, product_name, aisle_id, department_id]
# Index: []

# %%
with open('products.csv', encoding='utf-8') as f:
    for i, line in enumerate(f):
        if len(line.strip().split(',')) != 4:
            print(f"erroneous row: {i+1} - {line}")
# Out:
# erroneous row: 31 - 30,"Three Cheese Ziti, Marinara with Meatballs",38,1
#
# erroneous row: 49 - 48,"School Glue, Washable, No Run",87,17
#
# erroneous row: 68 - 67,"Jelly, Blackberry",88,13
#
# erroneous row: 69 - 68,"Pancake Mix, Buttermilk",130,14
#
# erroneous row: 76 - 75,"Hemp Protein, Organic",65,11
#
# erroneous row: 87 - 86,"Camilia, Single Liquid Doses",6,2
#
# erroneous row: 102 - 101,"Bread, Healthy Whole Grain",112,3
#
# erroneous row: 112 - 111,"Fabric Softener, Geranium Scent",75,17
#
# erroneous row: 140 - 139,"Zita Cut, No. 118",131,9
#
# erroneous row: 153 - 152,"3 in 1 Soap for Every Man, Cucumber & Lemon",25,11
#
# erroneous row: 154 - 153,"Fabric Refresher Meadows & Rain Air Freshener (1 Count, 27 oz)  Air Care",75,17
#
# erroneous row: 155 - 154,"Corn Dogs, Mini, Honey Crunchy Flavor",129,1
#
# erroneous row: 160 - 159,"Calcium Adult Gummy Vitamins, Orange Cherry & Strawberry",47,11
#
# erroneous row: 204 - 203,"Rescue Remedy, Spray",11,11
#
# erroneous row: 217 - 216,"Gluten Free Oatmeal, Variety Pack",130,14
#
# erroneous row: 218 - 217,"String Cheese, Mozzarella",108,16
#
# erroneous row: 250 - 249,"Pinot Grigio, California, 2010",62,5
#
# erroneous row: 251 - 250,"Authentic Deep Dish, Spinach & Garlic Pizza",79,1
#
# erroneous row: 253 - 252,"Waffles, Red Berry",121,14
#
# erroneous row: 256 - 255,"Cold Remedy, Quick Dissolve Tablets, Cherry Flavor",11,11
#
# erroneous row: 298 - 297,"Write Bros Ball Point Pens, Cap-Pen, Medium (1.0 mm), Black Ink",100,21
#
# erroneous row: 302 - 301,"Biotin 10,000mcg Maximum Strength",47,11
#
# erroneous row: 304 - 303,"Candy, Original",45,19
#
# erroneous row: 311 - 310,"Crackers, Puffed, Corn, Quinoa & Sesame",78,19
#
# erroneous row: 321 - 320,"Glycerine Soap, Pure and Natural, Cucumber",25,11
#
# erroneous row: 328 - 327,"Green Peas, Organic, Petite",116,1
#
# erroneous row: 338 - 337,"Soap, Pure-Castile, 18-in-1 Hemp, Lavender",25,11
#
# erroneous row: 343 - 342,"Complete Health Deboned Chicken, Chicken Meal and Rice Cat Food",41,8
#
# erroneous row: 348 - 347,"Vegetable Salad Kit, Sweet Kale",123,4
#
# erroneous row: 402 - 401,"Flat Floss, Antiplaque, Naturally Waxed, Spearmint",20,11
#
# erroneous row: 432 - 431,"Ice Cream, Cookies & Cream",37,1
#
# erroneous row: 448 - 447,"Tea, Superflower, Hibiscus, Blueberry, Caffeine-Free, Bags",94,7
#
# erroneous row: 452 - 451,"Almond Spread, Dark Chocolate",88,13
#
# erroneous row: 468 - 467,"Soup, Lower Sodium, Organic, Split Pea",69,15
#
# erroneous row: 483 - 482,"Gentle Clean Foaming Face Cleanser, 6.7 fl oz Female Skin Care",73,11
#
# erroneous row: 488 - 487,"Can/Bottle Opener, Chrome",10,17
#
# erroneous row: 493 - 492,"Couscous, Israeli, Garlic Jalapeno",63,9
#
# erroneous row: 503 - 502,"Frozen Desserts, Fit, Salted Caramel",37,1
#
# erroneous row: 535 - 534,"Tomato Paste with Basil, Oregano & Garlic Flavor",81,15
#
# erroneous row: 551 - 550,"Granola, Veritas, Organic",57,14
#
# erroneous row: 552 - 551,"Riesling, Mosel, 2014",62,5
#
# erroneous row: 594 - 593,"Linguine, No. 6",131,9
#
# erroneous row: 613 - 612,"Rice, Extra Long Grain, Enriched",63,9
#
# erroneous row: 614 - 613,"Infinity Always Infinity Size 2 Super Pads with Wings, Unscented, 16 ct Feminine Care",126,11
#
# erroneous row: 626 - 625,"Chicken Breast Nuggets, Dinosaur Shaped",34,1
#
# erroneous row: 644 - 643,"Kidney Beans, Dark, Premium",30,6
#
# erroneous row: 646 - 645,"Prenatal One, Tablets",47,11
#
# erroneous row: 654 - 653,"Flax, Oat Bran & Whole Wheat Flour Tortillas",128,3
#
# erroneous row: 658 - 657,"Nutrition Bar, Raw Organic, Pineapple Almond + Raw Protein",3,19
#
# erroneous row: 668 - 667,"Automatic Dish Packs, Lemon Verbena Scent",75,17
#
# erroneous row: 671 - 670,"Coconut Drink, Vanilla",91,16
#
# erroneous row: 676 - 675,"Thin Cakes, Puffed Multigrain",78,19
#
# erroneous row: 690 - 689,"Antibacterial, Pomegranate & Tangerine Hand Soap with Moisturizer",127,11
#
# erroneous row: 729 - 728,"Wraps, Turmeric",128,3
#
# erroneous row: 737 - 736,"Beer, IPA",27,5
#
# erroneous row: 783 - 782,"85% Lean, 15% Fat Ground Turkey (013021)",49,12
#
# erroneous row: 796 - 795,"Organic Fuel, High Protein Milk Shake, Vanilla",65,11
#
# erroneous row: 839 - 838,"Goat Cheese, Spreadable, Breakfast, Fig",51,13
#
# erroneous row: 849 - 848,"Cat Food, Premium, Adult Cat Formula",41,8
#
# erroneous row: 859 - 858,"Pomegranate Coconut Sparkling Probiotic Drink, Organic",31,7
#
# erroneous row: 894 - 893,"Vitamin E Oil 45,000 IU",109,11
#
# erroneous row: 901 - 900,"Fava Crisps, Santa Barbara Ranch",107,19
#
# erroneous row: 903 - 902,"Baked Rice Crisps, Sour Cream & Wasabi, Medium",78,19
#
# erroneous row: 905 - 904,"Tofu, Gluten Free, Garlic Pepper",14,20
#
# erroneous row: 912 - 911,"Protein Shake, Organic, Banana Creme",64,7
#
# erroneous row: 915 - 914,"Cold & Cough Formula, Effervescent Tablets, Citrus",11,11
#
# erroneous row: 928 - 927,"Cabernet Sauvignon, Central Coast, 2011",28,5
#
# erroneous row: 939 - 938,"Disinfectant Spray, Crisp Linen Scent",114,17
#
# erroneous row: 953 - 952,"Flaxseed Meal, Whole Ground",17,13
#
# erroneous row: 1021 - 1020,"Penne Rigate, 100% Organic Einkorn",131,9
#
# erroneous row: 1052 - 1051,"Silverware, Metallic",111,17
#
# erroneous row: 1058 - 1057,"Basil, Asiago & Pine Nut Pesto Ravioli",13,20
#
# erroneous row: 1081 - 1080,"Salad, Cobb",123,4
#
# erroneous row: 1090 - 1089,"Coffee, Gourmet, All-Purpose Grind, Medium, 100% Colombian, Decaf",26,7
#
# erroneous row: 1092 - 1091,"Pennsylvania Woodlands, Mushroom Barley Soup Mix",69,15
#
# erroneous row: 1148 - 1147,"Pop Up Notes, 3\"" X 3\""",87,17
#
# erroneous row: 1151 - 1150,"AFC Sushi Spicy Salmon Roll Prepared In Store, Ready To Eat",13,20
#
# erroneous row: 1164 - 1163,"Freshener, Room & Fabric, Relax, Lavender with Vanilla",101,17
#
# erroneous row: 1169 - 1168,"White Wine Winemaker's Blend California, 2010",62,5
#
# erroneous row: 1198 - 1197,"Plates, Ultra, 10-1/16 Inch",111,17
#
# erroneous row: 1207 - 1206,"Noodle Soup, Shin Cup, Gourmet Spicy",66,6
#
# erroneous row: 1218 - 1217,"Select-A-Size Paper Towels, White, 2 Huge Rolls = 5 Regular Rolls  Towels/Napkins",54,17
#
# erroneous row: 1261 - 1260,"Curry Powder, Oriental",66,6
#
# erroneous row: 1274 - 1273,"Ramen, Reduced Sodium, Asian Vegetable",66,6
#
# erroneous row: 1302 - 1301,"Cereal, Panda Puffs, Peanut Butter",121,14
#
# erroneous row: 1308 - 1307,"Tortilla Chips, Yellow Corn",107,19
#
# erroneous row: 1310 - 1309,"Tooth Gel, with Xylitol, Kid's, Natural Bubble Gum",20,11
#
# erroneous row: 1321 - 1320,"Dishwasher Detergent Pacs, Natural, Free & Clear",74,17
#
# erroneous row: 1329 - 1328,"Nutrition Bar, Dark Chocolate Pomegranate",3,19
#
# erroneous row: 1338 - 1337,"Yogurt, Sheep Milk, Strawberry",120,16
#
# erroneous row: 1346 - 1345,"Merlot, Alexander Valley, Sonoma County, 2009",28,5
#
# erroneous row: 1357 - 1356,"Sweet Potato, White Beans & Cinnamon Stage 2",92,18
#
# erroneous row: 1363 - 1362,"Baking Mix, Brownie",17,13
#
# erroneous row: 1370 - 1369,"Sauvignon Blanc, California, 2011",62,5
#
# erroneous row: 1411 - 1410,"Family Style Pizza Dough, Classic Crust",97,13
#
# erroneous row: 1412 - 1411,"Hummus, Roasted Garlic",67,20
#
# erroneous row: 1413 - 1412,"Sauce with salt, spices and pepper Seasoning",104,13
#
# erroneous row: 1415 - 1414,"Potato Pancake Mix, Vegetable",33,6
#
# erroneous row: 1475 - 1474,"Wax Peppers, Sweet Banana",110,13
#
# erroneous row: 1510 - 1509,"Nibblers, Mini-Ears of Extra Sweet Corn-on-the-Cob",116,1
#
# erroneous row: 1516 - 1515,"Preserves, Red Raspberry",88,13
#
# erroneous row: 1521 - 1520,"Rice Wine Vinegar, Seasoned",19,13
#
# erroneous row: 1530 - 1529,"Parsley, Italian (Flat), New England Grown",16,4
#
# erroneous row: 1546 - 1545,"Healthy Grains Granola Bar, Vanilla Blueberry",3,19
#
# erroneous row: 1576 - 1575,"Melba Toast, Classic",78,19
#
# erroneous row: 1598 - 1597,"Soy Sauce, Tamari, Organic, Gluten-Free, Less Sodium",66,6
#
# erroneous row: 1599 - 1598,"Maple Syrup, Organic",29,13
#
# erroneous row: 1607 - 1606,"Yogurt, Coconut Non-Dairy, Low Fat, Blueberry",120,16
#
# erroneous row: 1610 - 1609,"Egg, Uncured Bacon & Cheese Scramble Cups",38,1
#
# erroneous row: 1613 - 1612,"Everything Bagel,kattle Boiled & Hearth Baked Slice",93,3
#
# erroneous row: 1619 - 1618,"Lasagna, Vegetable, with Daiya Cheeze",38,1
#
# erroneous row: 1633 - 1632,"Skin Gel, Unscented",118,11
#
# erroneous row: 1634 - 1633,"Pancake & Waffle Mix, Almond Flour",130,14
#
# erroneous row: 1659 - 1658,"Double Superfine Mustard Powder, Original English",104,13
#
# erroneous row: 1671 - 1670,"Dog Food, Adult, Lamb & Rice",40,8
#
# erroneous row: 1735 - 1734,"Diced Tomatoes with Chilies, Onion & Cilantro",81,15
#
# erroneous row: 1737 - 1736,"Melatonin, Fast Dissolve, 5 mg, Tablets, Natural Strawberry Flavor & Sweeteners",6,2
#
# erroneous row: 1780 - 1779,"Jam, Fig & Ginger",88,13
#
# erroneous row: 1782 - 1781,"Highlighting Conditioner, Henna Gold",22,11
#
# erroneous row: 1794 - 1793,"Citrus Beverage, Sparkling, with Natural Pulp",77,7
#
# erroneous row: 1825 - 1824,"Frozen Desserts, Cookies and Cream",37,1
#
# erroneous row: 1854 - 1853,"Fabric Softener Dryer Sheets, Outdoor Fresh scent",75,17
#
# erroneous row: 1856 - 1855,"1% Hydrocortisone Anti-Itch Cream, Tube Anti-Itch",118,11
#
# erroneous row: 1866 - 1865,"Cookies, Ginger Snap",61,19
#
# erroneous row: 1877 - 1876,"Black Pepper, Medium Grind",104,13
#
# erroneous row: 1878 - 1877,"Juice Blend, Mega Antioxidant",98,7
#
# erroneous row: 1879 - 1878,"Peanut Butter, Creamy, No Salt Added",88,13
#
# erroneous row: 1907 - 1906,"Toothpaste, Fluoride-Free, Propolis & Myrrh, Fennel",20,11
#
# erroneous row: 1915 - 1914,"Original Habanero Pepper Sauce, XXXTra Hot Sauce",72,13
#
# erroneous row: 1930 - 1929,"Zucchini Squash, Baby Courgette",123,4
#
# erroneous row: 1937 - 1936,"Diet Tangerine Lime Premium Soda, Zero Calories, Sugar Free, No Caffeine",77,7
#
# erroneous row: 1997 - 1996,"Soda, Cucumber",77,7
#
# erroneous row: 2009 - 2008,"Apple, Carrot, & Spinach Super Smoothie",92,18
#
# erroneous row: 2034 - 2033,"Smart Ones Egg, Sausage & Cheese Breakfast Wrap",52,1
#
# erroneous row: 2036 - 2035,"Miniature Dog Treats, Chicken Formula",40,8
#
# erroneous row: 2053 - 2052,"Potato Chips, Organic, Sea Salt",107,19
#
# erroneous row: 2067 - 2066,"Body Wash, Nourishing, Classic Carrot Scent, For Normal to Dry Skin",127,11
#
# erroneous row: 2088 - 2087,"Crunchy Kale, Naked",107,19
#
# erroneous row: 2091 - 2090,"Milk, Goat",84,16
#
# erroneous row: 2095 - 2094,"Skin DeTox, Tea Bags",94,7
#
# erroneous row: 2113 - 2112,"Peppercorns, Rainbow",104,13
#
# erroneous row: 2151 - 2150,"Sauvignon Blanc, Mendocino, 2007",62,5
#
# erroneous row: 2156 - 2155,"Beauty Balm, All in One, Sheer Tint, with SPF 30",109,11
#
# erroneous row: 2165 - 2164,"Waffles, Sweet Belgian, Vanilla",52,1
#
# erroneous row: 2256 - 2255,"Sesame Oil, Unrefined",19,13
#
# erroneous row: 2260 - 2259,"White Label Antiperspirant, Night",80,11
#
# erroneous row: 2264 - 2263,"Arrabbiata Sauce, Hot",9,9
#
# erroneous row: 2270 - 2269,"Turkey Bar, Almond + Cranberry",3,19
#
# erroneous row: 2280 - 2279,"Olive Oil, Extra Virgin, Organic",19,13
#
# erroneous row: 2283 - 2282,"Macaroons, Dark Cacao",61,19
#
# erroneous row: 2297 - 2296,"Notebook, 3 Subject, College Rule, 120 Sheets",87,17
#
# erroneous row: 2299 - 2298,"Muffins, Mini, Flax, Chocolate Brownie",8,3
#
# erroneous row: 2354 - 2353,"Multivitamin, Kids Complete, Gummies",6,2
#
# erroneous row: 2363 - 2362,"Pretzel Sticks, Thin",107,19
#
# erroneous row: 2382 - 2381,"Curry, Condensed, Mild, Korma Masala",76,6
#
# erroneous row: 2399 - 2398,"Bean Threads, 3 Pack Tray",66,6
#
# erroneous row: 2404 - 2403,"Almond Butter, Vanilla Espresso",88,13
#
# erroneous row: 2413 - 2412,"Dual Scented Oil Refill, Hawaiian Aloha",101,17
#
# erroneous row: 2421 - 2420,"Poultry Grill & Broil, Blend",104,13
#
# erroneous row: 2430 - 2429,"Seriously Sharp Cheddar Cheese Cracker Cut Slices,",21,16
#
# erroneous row: 2450 - 2449,"Tri Fun Pack Fruit Loops, Cocoa Krispies; Apple Jacks",121,14
#
# erroneous row: 2479 - 2478,"Miso, Dark Aged",66,6
#
# erroneous row: 2485 - 2484,"Organic Kiwi, Banana, & Apple with Super Grain Salba",50,19
#
# erroneous row: 2486 - 2485,"Tea, Mental Focus, Bags",94,7
#
# erroneous row: 2505 - 2504,"Bread, Watsonville Sourdough",112,3
#
# erroneous row: 2516 - 2515,"Evaporated Milk,",17,13
#
# erroneous row: 2527 - 2526,"Peanuts, Extra Large Gourmet Virginia, Salted",117,19
#
# erroneous row: 2530 - 2529,"Tortilla Sticks, Veggie",107,19
#
# erroneous row: 2543 - 2542,"Hand Wash, Foaming, Green Tea + Aloe",127,11
#
# erroneous row: 2576 - 2575,"Delights Chicken Sausage, Egg Whites, & Cheese English Muffin",52,1
#
# erroneous row: 2581 - 2580,"Beef Jerky, Grass-Fed, Spicy",23,19
#
# erroneous row: 2595 - 2594,"Old World Gluten-Free Pizza Crust, Napoli Herb",128,3
#
# erroneous row: 2596 - 2595,"Tender white meat chicken, vegetables & rice in a cheddar cheese sauce Grandma's Chicken & Vegetable Rice Bake",38,1
#
# erroneous row: 2650 - 2649,"Gnocchi, Garlic & Basil",9,9
#
# erroneous row: 2654 - 2653,"Chik'n Cutlets, Cranberry & Goats Cheese",42,1
#
# erroneous row: 2671 - 2670,"Yogurt, Organic, Lowfat, Plain",120,16
#
# erroneous row: 2702 - 2701,"Uplift, Balance & Calm Essential Oils",19,13
#
# erroneous row: 2710 - 2709,"Dijon Mustard Blend, Rich Country",72,13
#
# erroneous row: 2720 - 2719,"Salad, Chopped, Garden Vegetable",123,4
#
# erroneous row: 2724 - 2723,"Pro Health Complete Crest Pro-Health Advanced Mouthwash with Extra Deep Clean, Clean Mint flavor 500 ML Oral Rinse",20,11
#
# erroneous row: 2727 - 2726,"Ice Cream, Super Premium, Mint Chocolate Chip",37,1
#
# erroneous row: 2785 - 2784,"Yogurt, Drinkable, Wild Blueberry",120,16
#
# erroneous row: 2803 - 2802,"Get Up, Stand Up K-Cup Pods Light Roast Coffee Mild, Bright, Floral",26,7
#
# erroneous row: 2820 - 2819,"Tulsi-Holy Basil, Vegetarian Capsules",47,11
#
# erroneous row: 2830 - 2829,"Organic Stage 2 Apple, Banana & Butternut Squash Baby Food",92,18
#
# erroneous row: 2871 - 2870,"Clean Energy Drink, Lemon Lemongrass",94,7
#
# erroneous row: 2875 - 2874,"Melatonin, 3 mg, Vegetarian Capsules",6,2
#
# erroneous row: 2876 - 2875,"Cumin, 100% Organic, Ground",104,13
#
# erroneous row: 2893 - 2892,"Ultimate Healing Lotion, Aloe",127,11
#
# erroneous row: 2923 - 2922,"Bathroom Tissue, Unscented, Regular Rolls, 2-Ply",54,17
#
# erroneous row: 2924 - 2923,"Mighty 4 Essential Tots Spinach, Kiwi, Barley & Greek Yogurt Nutrition Blend",92,18
#
# erroneous row: 2934 - 2933,"Crunchy, Cocoa Dusted Banana Chips",50,19
#
# erroneous row: 2944 - 2943,"Low Fat, Small Curd 1% Milkfat No Salt Added Cottage Cheese",108,16
#
# erroneous row: 2948 - 2947,"Tea, Woman's Moon Cycle, Caffeine Free, Bags",94,7
#
# erroneous row: 2963 - 2962,"Milk, Reduced Fat, 2% Milkfat",84,16
#
# erroneous row: 2976 - 2975,"Napkins, 2-Ply, Mega Pack",54,17
#
# erroneous row: 2995 - 2994,"Sushi Nori, Pacific, Organic",66,6
#
# erroneous row: 3019 - 3018,"Egg Noodles, Toasted Barley Shape",33,6
#
# erroneous row: 3029 - 3028,"Thai Spice, Organic",104,13
#
# erroneous row: 3036 - 3035,"Mints, Sugar Free, Pep O Mint",46,19
#
# erroneous row: 3050 - 3049,"Fortifying, Sleek & Shine Conditioner",22,11
#
# erroneous row: 3057 - 3056,"Ravioli, Five Cheese, Value Pack",12,9
#
# erroneous row: 3082 - 3081,"Organic Creamies Strawberry, Raspberry & Carrot Freeze-Dried Fruit Snacks",92,18
#
# erroneous row: 3103 - 3102,"Potato Chips, Reduced Fat, Unsalted",107,19
#
# erroneous row: 3124 - 3123,"Niblets Whole Kernel Sweet Corn, Extra Sweet",81,15
#
# erroneous row: 3132 - 3131,"Take Alongs, Medium Bowls",85,17
#
# erroneous row: 3179 - 3178,"Healthy Trinity, 3 in 1, Capsules",70,11
#
# erroneous row: 3182 - 3181,"Juice Cocktail, Cranberry Blood Orange",98,7
#
# erroneous row: 3213 - 3212,"Vinegar, Red Wine",19,13
#
# erroneous row: 3234 - 3233,"Organic Turkey with Rosemary, Sage & Thyme Bone Broth",69,15
#
# erroneous row: 3265 - 3264,"Muesli, Bircher (Unsweetened)",57,14
#
# erroneous row: 3268 - 3267,"Diet Root Beer, No Caffeine",77,7
#
# erroneous row: 3273 - 3272,"Pancake Batter, Original",52,1
#
# erroneous row: 3327 - 3326,"Chocolate Candies, Peanut",45,19
#
# erroneous row: 3359 - 3358,"Rising Crust Supreme (Sausage, Pepperoni, Red Peppers, Green Peppers, Onions, Black Olives) Frozen Pizza",79,1
#
# erroneous row: 3367 - 3366,"Soup Mix, Sausage & Lentil, Indiana Harvest",63,9
#
# erroneous row: 3370 - 3369,"Pinot Noir, Vin de Pays d'Oc, 2006",28,5
#
# erroneous row: 3373 - 3372,"Original Unsweetened Coconut, Almond, and Chia Drink",91,16
#
# erroneous row: 3379 - 3378,"Rescue Remedy for Pets, Dropper",40,8
#
# erroneous row: 3387 - 3386,"Coldpuree Organic Stage 2 Apple, Sweet Potato, Pineapple and Oat Baby Food",100,21
#
# erroneous row: 3440 - 3439,"Thick Sliced Canadian, Bacon Natural Hickory Smoked",106,12
#
# erroneous row: 3444 - 3443,"Pardina!, Lentils",63,9
#
# erroneous row: 3465 - 3464,"Organic Butterhead (Boston, Butter, Bibb) Lettuce",83,4
#
# erroneous row: 3478 - 3477,"Fruit & Veggie 1,2,3",121,14
#
# erroneous row: 3479 - 3478,"Designer Paper Plates, 10.25\""",111,17
#
# erroneous row: 3498 - 3497,"Grape Wine, Delicious Red",28,5
#
# erroneous row: 3524 - 3523,"Dark Chocolate, Firecracker, 60% Cacao",45,19
#
# erroneous row: 3526 - 3525,"Organic Icelandic, Nonfat, Blueberry Yogurt",120,16
#
# erroneous row: 3532 - 3531,"Couscous, Original Plain",63,9
#
# erroneous row: 3553 - 3552,"Bologna, German Brand",96,20
#
# erroneous row: 3569 - 3568,"Quinoa Cluster, Almond",125,19
#
# erroneous row: 3582 - 3581,"Ultra Stain Release Liquid Laundry Detergent, 92 oz, 48 loads Laundry",75,17
#
# erroneous row: 3613 - 3612,"Peperoncini, Golden Greek",110,13
#
# erroneous row: 3626 - 3625,"Original, Hummus Chips",107,19
#
# erroneous row: 3680 - 3679,"Olives, Hand Stuffed, Bleu Cheese",110,13
#
# erroneous row: 3700 - 3699,"Chard, Green, New England Grown",83,4
#
# erroneous row: 3704 - 3703,"Plates, 10-1/16 Inch",111,17
#
# erroneous row: 3709 - 3708,"Lean Protein & Fiber Bars, Chocolate Almond Brownie",65,11
#
# erroneous row: 3731 - 3730,"Crumbled Feta Cheese, Fat Free",21,16
#
# erroneous row: 3749 - 3748,"Pure Care Dry Oil for Dull, Dry Hair, Non-Greasy Conditioner",22,11
#
# erroneous row: 3751 - 3750,"Tea Tree Oil, 100% Australian",109,11
#
# erroneous row: 3768 - 3767,"Deodorant, Tea Tree Oil",80,11
#
# erroneous row: 3776 - 3775,"Ham Steak, Boneless, Honey Cured",7,12
#
# erroneous row: 3783 - 3782,"Bread, Jewish Rye",112,3
#
# erroneous row: 3807 - 3806,"Homestyle Meals Pumpkin, White Beans & Kale Organic Baby Food",92,18
#
# erroneous row: 3816 - 3815,"Worcestershire Sauce, Bourbon Barrel Aged",72,13
#
# erroneous row: 3836 - 3835,"Coconut Water, Pure Organic",98,7
#
# erroneous row: 3868 - 3867,"Antiperspirant Deodorant, Fresh",80,11
#
# erroneous row: 3876 - 3875,"Cough & Bronchial Syrup with Zinc Formula, Maximum Strength",11,11
#
# erroneous row: 3878 - 3877,"Sauvignon Blanc, Monterey, 2011",62,5
#
# erroneous row: 3888 - 3887,"Raw Honey, Organic",29,13
#
# erroneous row: 3890 - 3889,"Tomatoes, Crushed",81,15
#
# erroneous row: 3922 - 3921,"2nd Foods Organic Fruit & Veggies - Apples, Zucchini, Spinach & Strawberries",92,18
#
# erroneous row: 3924 - 3923,"Cashew, Sesame & Pimento Spread",51,13
#
# erroneous row: 3925 - 3924,"Yogurt, Creamline, Orange Creme",120,16
#
# erroneous row: 3939 - 3938,"Vanilla Extract, Organic",17,13
#
# erroneous row: 3945 - 3944,"Dog Chew, USA Rawhide, Chicken Flavored, 7 Inch",40,8
#
# erroneous row: 4011 - 4010,"Dish Brush, Soap Dispensing",10,17
#
# erroneous row: 4022 - 4021,"Patties, Beef, Quarter Pound",34,1
#
# erroneous row: 4027 - 4026,"Honey Patties, Chocolate Almond",3,19
#
# erroneous row: 4030 - 4029,"Organic Corn Thins, Original",107,19
#
# erroneous row: 4042 - 4041,"Melatonin Adult Gummies, White Tea & Passion Fruit, Sugar Free",47,11
#
# erroneous row: 4066 - 4065,"Bean, Cheese, Rice, Salsa Wrap",30,6
#
# erroneous row: 4078 - 4077,"Cola, Agave",77,7
#
# erroneous row: 4083 - 4082,"Hearts of Palm, Sliced",95,15
#
# erroneous row: 4085 - 4084,"Pain Relieving Rub, Topical Analgesic Cream",133,11
#
# erroneous row: 4097 - 4096,"Piquante Peppers, Hot, Sweet, Whole",81,15
#
# erroneous row: 4109 - 4108,"Almonds, Marcona",117,19
#
# erroneous row: 4121 - 4120,"Royal Tea, Organic Black Tea",94,7
#
# erroneous row: 4124 - 4123,"Light Wheat Muffin Sandwiches With Egg Whites, Turkey Sausage & Cheese",52,1
#
# erroneous row: 4156 - 4155,"Creme Pie, Chocolate",119,1
#
# erroneous row: 4171 - 4170,"Cereal, Veganic Sprouted, Spelt Flakes",121,14
#
# erroneous row: 4185 - 4184,"Pepper, White",104,13
#
# erroneous row: 4189 - 4188,"Premium Marinara Sauce, Original Recipe",9,9
#
# erroneous row: 4190 - 4189,"Yogurt, Goat Milk, and Fruit, Banana & Natural Vanilla Bean with Pear, 2+",120,16
#
# erroneous row: 4194 - 4193,"Ravioli, Spinach & Cheese",12,9
#
# erroneous row: 4199 - 4198,"Dishwasher Detergent, Lemon Scent with Clorox",74,17
#
# erroneous row: 4200 - 4199,"Organic Turkey, Brown Rice & Chicken Adult Wet Cat Food",41,8
#
# erroneous row: 4214 - 4213,"Delights Turkey Sausage, Egg Whites, & Cheese English Muffin",52,1
#
# erroneous row: 4231 - 4230,"Leave-In Conditioner, Argan Oil Plus +, Moisture Rich",22,11
#
# erroneous row: 4233 - 4232,"Ambrosia, Medium Roast",26,7
#
# erroneous row: 4238 - 4237,"Pinot Noir, California, 2011",28,5
#
# erroneous row: 4286 - 4285,"Sangria, Tradicional, Fresh Citrus",134,5
#
# erroneous row: 4344 - 4343,"Hot Cocoa Mix, Milk Chocolate Flavor",90,7
#
# erroneous row: 4349 - 4348,"Golden Berries, Vine Ripened, Organic",117,19
#
# erroneous row: 4359 - 4358,"Crispbreads, Thick Cut, Smoked Dutch Gouda and Garlic",78,19
#
# erroneous row: 4398 - 4397,"Eye Makeup Remover, Chamomile & Green Tea",109,11
#
# erroneous row: 4405 - 4404,"Le Bon Basil, Zucchini & Parmesan Dip",67,20
#
# erroneous row: 4428 - 4427,"Figs, Black Mission",117,19
#
# erroneous row: 4431 - 4430,"Macaroons, Coconut Vanilla",61,19
#
# erroneous row: 4438 - 4437,"Cardamom, Ground",104,13
#
# erroneous row: 4445 - 4444,"Clotted Cream, English Luxury",53,16
#
# erroneous row: 4465 - 4464,"Fruit Spread, Deluxe, Golden Peach",88,13
#
# erroneous row: 4491 - 4490,"Toothpaste, Fluoride-Free, Antigingivitis, Peppermint Sage",20,11
#
# erroneous row: 4507 - 4506,"Rick Sticks, Vermicelli",66,6
#
# erroneous row: 4513 - 4512,"Legal Pads, Canary, 3 Pack",87,17
#
# erroneous row: 4532 - 4531,"Ice Cream, Chocolate",37,1
#
# erroneous row: 4559 - 4558,"Sleep Aid, Calms Forte, Tablets",100,21
#
# erroneous row: 4574 - 4573,"Gum, Sugarfree, Winterfrost",46,19
#
# erroneous row: 4576 - 4575,"Beef Jerky, Teriyaki",23,19
#
# erroneous row: 4578 - 4577,"Spaghetti O's, Meatballs",59,15
#
# erroneous row: 4598 - 4597,"Organic Tempeh, Garden Veggie",14,20
#
# erroneous row: 4599 - 4598,"Toilet Bowl Cleaner, Automatic, Bleach",114,17
#
# erroneous row: 4658 - 4657,"Disinfectant, Botanical, Citrus Scent",114,17
#
# erroneous row: 4698 - 4697,"Eggs, Cheese & Turkey Sausage Breakfast Burrito",52,1
#
# erroneous row: 4700 - 4699,"Refried Beans, Green Chile & Lime",59,15
#
# erroneous row: 4716 - 4715,"Kitchen Cleaner + Bleach, Fresh Scent",114,17
#
# erroneous row: 4720 - 4719,"Quinoa & Brown Rice, Garlic and Herb",63,9
#
# erroneous row: 4726 - 4725,"Organic 3rd Foods Apples, Prunes & Oranges with Yogurt Baby Food Organic Purees Fruit with Yogurt",92,18
#
# erroneous row: 4729 - 4728,"Color Vibrancy Nourishing Conditioner, Anti-Oxidant (UV) Daily Care for Color-Treated Hair",22,11
#
# erroneous row: 4756 - 4755,"Palmetto Cheese, Pimiento Cheese with Bacon",108,16
#
# erroneous row: 4766 - 4765,"Salami, Italian Dry",96,20
#
# erroneous row: 4774 - 4773,"Dry Valencia Orange Soda, Lightly Sweetened",77,7
#
# erroneous row: 4788 - 4787,"Ravioli, Italian Sausage",12,9
#
# erroneous row: 4795 - 4794,"Pure Vegetable Oil Soap, Original Wood Cleaner, Concentrated",114,17
#
# erroneous row: 4803 - 4802,"Sesame Oil, Pure",66,6
#
# erroneous row: 4815 - 4814,"Salad Kit, Light Caesar",123,4
#
# erroneous row: 4817 - 4816,"Red, White & Blue Pop'ems",93,3
#
# erroneous row: 4832 - 4831,"Sparkling Water, Orange",115,7
#
# erroneous row: 4835 - 4834,"Garlic, Elephant",83,4
#
# erroneous row: 4843 - 4842,"Cannellini Beans, White Kidney Beans",59,15
#
# erroneous row: 4858 - 4857,"Chardonnay, Central Coast",62,5
#
# erroneous row: 4865 - 4864,"Milk, 2% Reduced Fat, Chocolate",84,16
#
# erroneous row: 4880 - 4879,"Milk, Fat Free",84,16
#
# erroneous row: 4897 - 4896,"Premium Dog Treats Peanut Butter Flavor, Medium Size",40,8
#
# erroneous row: 4912 - 4911,"Stage 2 Apple, Cinnamon, & Granola Baby Food",92,18
#
# erroneous row: 4924 - 4923,"Organic Pear, Strawberry, Beet & Kiwi Fruit & Veggie Twist",92,18
#
# erroneous row: 4936 - 4935,"Choco Chews, Organic",45,19
#
# erroneous row: 4968 - 4967,"Granola Bars, Crunchy, Macaroon Crunch",3,19
#
# erroneous row: 4971 - 4970,"Little Bites Seasonal Favorites, Pumpkin Muffins",61,19
#
# erroneous row: 4988 - 4987,"Hint of Mint, Rich Chocolate with a Splash of Mint Fit Frozen Dessert",37,1
#
# erroneous row: 5035 - 5034,"P3 Smoked Ham, Cheese & Cashews Portable Protein Packs",96,20
#
# erroneous row: 5041 - 5040,"All-Purpose Sauce, Kale Tahini",67,20
#
# erroneous row: 5057 - 5056,"Bar-B-Que Sauce, Roasted Garlic Honey",5,13
#
# erroneous row: 5076 - 5075,"Olives, Gourmet Black, Kalamata, Halved",110,13
#
# erroneous row: 5079 - 5078,"Soap, French Milled Oval, Climbing Wild Rose",25,11
#
# erroneous row: 5087 - 5086,"Almondmilk, Pure, Chocolate Protein",64,7
#
# erroneous row: 5096 - 5095,"PODS Laundry Detergent, Spring Meadow, 72 count, Designed for Regular and HE Washers Laundry",75,17
#
# erroneous row: 5101 - 5100,"Coffee, Coffee BuzzBuzzBuzz!® Ice Cream",37,1
#
# erroneous row: 5115 - 5114,"Peach,  Apricot & Banana Stage 2 Baby Food",92,18
#
# erroneous row: 5118 - 5117,"Cloves, Ground",104,13
#
# erroneous row: 5125 - 5124,"Freshly made pasta layered with seasoned meat sauce, tomato sauce and Real low-fat Ricotta cheese Lasagna Italiano",38,1
#
# erroneous row: 5140 - 5139,"Anti-Gas, Ultra Strength, 180 mg, Softgels",70,11
#
# erroneous row: 5178 - 5177,"Kettle Chips, Sweet Potato, Sea Salt",107,19
#
# erroneous row: 5180 - 5179,"Spoon, Melamine",10,17
#
# erroneous row: 5183 - 5182,"Flour, TigerNut",17,13
#
# erroneous row: 5228 - 5227,"Deodorant, Natural, Fragrance-Free",80,11
#
# erroneous row: 5253 - 5252,"Champagne, Sparkling, California, Brut Cuvee",62,5
#
# erroneous row: 5257 - 5256,"Fruit Spread, Concord Grape",88,13
#
# erroneous row: 5284 - 5283,"Lager, Jamaican Style",27,5
#
# erroneous row: 5291 - 5290,"Cheese, Smoked Provolone",2,16
#
# erroneous row: 5300 - 5299,"Coffee, Gourmet, All Purpose Grind, Medium, Hawaiian Blend",26,7
#
# erroneous row: 5315 - 5314,"Supremely Spicy Hummus, Family Size",67,20
#
# erroneous row: 5321 - 5320,"Sausage, Parm & Ravioli",12,9
#
# erroneous row: 5341 - 5340,"Turkey Jerky, Lemon Garlic",23,19
#
# erroneous row: 5348 - 5347,"Adults MultiGummies, Cherry, Berry, Orange",47,11
#
# erroneous row: 5353 - 5352,"Medium Nails, Assorted Sizes & Types",87,17
#
# erroneous row: 5358 - 5357,"Organic Spelt Mini Pretzels, Low Sodium",107,19
#
# erroneous row: 5369 - 5368,"Healthy Smile Ridges, Large Dental Dog Snacks",40,8
#
# erroneous row: 5400 - 5399,"Liquid Laundry Detergent, Mountain Spring scent",75,17
#
# erroneous row: 5407 - 5406,"Triple Zero Vanilla, Blended Greek Nonfat Yogurt",120,16
#
# erroneous row: 5427 - 5426,"Chocolate, 40%, Creamy Milk",45,19
#
# erroneous row: 5428 - 5427,"Cheese, Marinated, Sheep & Goat Blend",2,16
#
# erroneous row: 5454 - 5453,"100% Juice, Organic, Pomegranate",98,7
#
# erroneous row: 5475 - 5474,"Crackers, Puffed, Lightly Salted Corn",78,19
#
# erroneous row: 5495 - 5494,"Egg, Basil Pesto, & Cheese Scramble",38,1
#
# erroneous row: 5501 - 5500,"Blended Juice Beverage, Mango Orange",113,1
#
# erroneous row: 5516 - 5515,"Energy Lightly Carbonated, Blackberry Cranberry",98,7
#
# erroneous row: 5524 - 5523,"Super C, 1000 mg, Tablets",47,11
#
# erroneous row: 5541 - 5540,"Chili with Beans, Vegetarian",59,15
#
# erroneous row: 5545 - 5544,"For Dry, Damaged Hair Triple Nutrition Conditioner",22,11
#
# erroneous row: 5556 - 5555,"Pretzels, 100% Whole Wheat",33,6
#
# erroneous row: 5577 - 5576,"Deli Fresh Maple Honey Ham, Bold, 97% Fat Free, Gluten Free",96,20
#
# erroneous row: 5585 - 5584,"Vitamin D3 Gummies, 1000 IU, Great Wild Berry Taste!",47,11
#
# erroneous row: 5598 - 5597,"Deep Green Blends, Kale",123,4
#
# erroneous row: 5624 - 5623,"Dentastix® Original, Treats for Toy/Small Dogs",40,8
#
# erroneous row: 5629 - 5628,"Rhodiola Rosea, Standardized, Premium Extract, Vegetarian Vcaps",47,11
#
# erroneous row: 5631 - 5630,"Soft Wraps, Gourmet, Multigrain, Extra Virgin Olive Oil",128,3
#
# erroneous row: 5640 - 5639,"Goji Berries, Yogurt Covered",117,19
#
# erroneous row: 5677 - 5676,"Freshmatic Automatic Ultra Spray Refill, Lavender & Chamomile",101,17
#
# erroneous row: 5746 - 5745,"Black & Green Tea, Organic, Chai, Bags",94,7
#
# erroneous row: 5753 - 5752,"Organic Qi'a Superfood Oatmeal, Cinnamon Pumpkin Seed",130,14
#
# erroneous row: 5756 - 5755,"Ground Cinnamon, 100% Organic",104,13
#
# erroneous row: 5757 - 5756,"Cloves, Whole, 100% Organic",104,13
#
# erroneous row: 5758 - 5757,"Nuts & Spices, Dark Chocolate Mocha Almond",3,19
#
# erroneous row: 5759 - 5758,"Cranberry Sauce, Whole Berry",99,15
#
# erroneous row: 5776 - 5775,"Pinot Noir, California 2010",28,5
#
# erroneous row: 5782 - 5781,"Rice Vegan Slices, Cheddar Flavor",91,16
#
# erroneous row: 5791 - 5790,"Sugar Free Chocolate Flavored Sundae Syrup, No Mess Cap!",103,19
#
# erroneous row: 5792 - 5791,"Cabbage, Napa, Table Cut",67,20
#
# erroneous row: 5802 - 5801,"Turkey, Pepperoni & Cheese Ready to Eat Meal Kit",4,9
#
# erroneous row: 5810 - 5809,"Cheese, Soft Ripened, Camembert",21,16
#
# erroneous row: 5811 - 5810,"Chianti Classico, 2006",28,5
#
# erroneous row: 5821 - 5820,"Black Tea, Organic, Masala Chai, Bags",94,7
#
# erroneous row: 5834 - 5833,"Conditioner, Fortifying, Sleek & Shine, Frizzy, Dry Unmanageable Hair",100,21
#
# erroneous row: 5839 - 5838,"Turmeric, Non-GMO Vegetarian Capsules",47,11
#
# erroneous row: 5849 - 5848,"Nice 'n Easy Root Touch-Up Kit, 004 Dark Brown",22,11
#
# erroneous row: 5903 - 5902,"Rice Crackers, Original",78,19
#
# erroneous row: 5920 - 5919,"Juice, Pineapple Coconut",98,7
#
# erroneous row: 5922 - 5921,"Deodorant, Liquid Rock, Sport, Tube",80,11
#
# erroneous row: 5923 - 5922,"Honest Face, Hand, & Baby Wipes",56,18
#
# erroneous row: 5948 - 5947,"Hot Pocket  Applewood Bacon, Egg and Low Fat Cheese Breakfast Sandwich",52,1
#
# erroneous row: 5954 - 5953,"Zin, Old Vine, Lodi, 2008",28,5
#
# erroneous row: 5991 - 5990,"Mustache & Beard Brush-In Color Gel, Medium Dark Brown M-40",22,11
#
# erroneous row: 6000 - 5999,"Semi-Soft Cheese, Ripened",21,16
#
# erroneous row: 6017 - 6016,"Sausage, Egg, & Cheese Croissant",52,1
#
# erroneous row: 6056 - 6055,"Tomato, Garlic & Onion Pasta Sauce",9,9
#
# erroneous row: 6064 - 6063,"Pregnancy Test, Test & Confirm",6,2
#
# erroneous row: 6065 - 6064,"Happy Tot Greek Yogurt Pomegranate, Apple & Beet Organic Superfoods",99,15
#
# erroneous row: 6069 - 6068,"Black Pepper, Fine Grind",104,13
#
# erroneous row: 6078 - 6077,"Traditional Crust Supreme (Sausage, Pepperoni, Green Peppers, Red Peppers, Onions) Pizza",79,1
#
# erroneous row: 6096 - 6095,"Yogurt, Greek, Traditional, Honey Flavored",120,16
#
# erroneous row: 6114 - 6113,"Natural Food Color Packets, Beet Red",97,13
#
# erroneous row: 6119 - 6118,"Plus Downy Clean Breeze Scent Liquid Laundry Detergent, 92 oz, 48 loads Laundry",75,17
#
# erroneous row: 6134 - 6133,"Ice Cream, Natural, French Vanilla",37,1
#
# erroneous row: 6213 - 6212,"White meat chicken, shredded cabbage, julienne yellow carrots and spicy red coconut flavored curry Thai-Style Chicken Spring Rolls",38,1
#
# erroneous row: 6242 - 6241,"Snacks, Original Mix",107,19
#
# erroneous row: 6299 - 6298,"Control Plus Scope Flavor Fixodent Plus Scope Superior Hold Adhesive Cream, 2 oz Denture Care",20,11
#
# erroneous row: 6300 - 6299,"Peppers, Organic Piquillo",81,15
#
# erroneous row: 6320 - 6319,"Sweet, Peeled Red Pimientos",81,15
#
# erroneous row: 6339 - 6338,"Red Classic, Sugar-Free",37,1
#
# erroneous row: 6344 - 6343,"Pizza Poppers, Three Cheese",129,1
#
# erroneous row: 6354 - 6353,"Natural Multi-Purpose Cleaner, Valencia Orange",114,17
#
# erroneous row: 6361 - 6360,"Mouthwash, Tea Tree Oil",20,11
#
# erroneous row: 6398 - 6397,"Hand Soap, Refill Size, Lemon & Eucalyptus",25,11
#
# erroneous row: 6399 - 6398,"Pizza Sauce, Premium, Pizzeria Style",9,9
#
# erroneous row: 6409 - 6408,"Redenbachers Popping Corn Gourmet Light Butter, Bonus Pack!",23,19
#
# erroneous row: 6412 - 6411,"Delights Honey Wheat Flatbread Turkey Sausage, Egg & Cheese",52,1
#
# erroneous row: 6425 - 6424,"Hearts of Palm, Whole",81,15
#
# erroneous row: 6481 - 6480,"Brewed Bars, Specialty, Craft Brewed Root Beer Float",37,1
#
# erroneous row: 6502 - 6501,"Decorating Icing, Pink",97,13
#
# erroneous row: 6512 - 6511,"Rooibos Tea, Moroccan Pomegranate Red",94,7
#
# erroneous row: 6525 - 6524,"Moscato, D'Asti, DOCG, 2011",28,5
#
# erroneous row: 6526 - 6525,"Seasoning, Poultry",104,13
#
# erroneous row: 6543 - 6542,"Protein Chips, BBQ Flavor",107,19
#
# erroneous row: 6544 - 6543,"Garam Masala, Organic",104,13
#
# erroneous row: 6549 - 6548,"Oat Revolution Steel Cut, Maple & brown Sugar",130,14
#
# erroneous row: 6554 - 6553,"Laundry Detergent, 2X Power, Lavender Scent",75,17
#
# erroneous row: 6605 - 6604,"Streak-Free Clean + Protect, Stainless Steel",114,17
#
# erroneous row: 6622 - 6621,"Melatonin, 1 mg, Liquid",6,2
#
# erroneous row: 6658 - 6657,"Almond Butter Protein +, Vanilla",88,13
#
# erroneous row: 6680 - 6679,"Organic 2nd Foods Apples, Blueberries & Spinach Baby Food",92,18
#
# erroneous row: 6697 - 6696,"Cooking Wine, White",19,13
#
# erroneous row: 6712 - 6711,"Chocolate, Butterfinger, Butterfinger Fudge Frozen Dairy Dessert Cones",37,1
#
# erroneous row: 6724 - 6723,"Palmiers, Petite",61,19
#
# erroneous row: 6742 - 6741,"Organic Chocotal, Ground",26,7
#
# erroneous row: 6745 - 6744,"Shikakai Soap, Organic Hand & Body, Spearmint Peppermint",25,11
#
# erroneous row: 6747 - 6746,"Vanilla Extract, Pure",104,13
#
# erroneous row: 6752 - 6751,"Drink Tabs, Strawberry Lemonade",64,7
#
# erroneous row: 6779 - 6778,"Soup, Golden Quinoa and Kale",1,20
#
# erroneous row: 6803 - 6802,"Toothpaste for Sensitive Teeth and Cavity Protection, Maximum Strength Prevent & Repair Gentle Mint Paste",20,11
#
# erroneous row: 6817 - 6816,"Scotch Kids 5\"" Scissors, Blunted, Red",87,17
#
# erroneous row: 6848 - 6847,"Magnesium Supplement, Raspberry-Lemon Flavor",6,2
#
# erroneous row: 6899 - 6898,"Green Tea, Organic",94,7
#
# erroneous row: 6912 - 6911,"Premium Dinner Napkins, 3-Ply",54,17
#
# erroneous row: 6917 - 6916,"Fresh Scentsations Carpet Odor Eliminator, Island Mist",114,17
#
# erroneous row: 6924 - 6923,"Organic 3rd Foods Peaches, Apricots & Carrots with Yogurt Baby Food Organic Purees Fruit/Veg with Yogurt",92,18
#
# erroneous row: 6931 - 6930,"Giant French Prunes, Pitted",99,15
#
# erroneous row: 6958 - 6957,"Herbal Tea, Cold & Flu, Tea Bags",94,7
#
# erroneous row: 6969 - 6968,"AFC Sushi Crunchy California Roll Special Prepared In Store, Ready To Eat",13,20
#
# erroneous row: 6983 - 6982,"Juice Drink, Fruit & Vegetable, Lavenade",98,7
#
# erroneous row: 6987 - 6986,"Diapers, Overnight, Free & Clear, Size 6 (35+ lbs)",56,18
#
# erroneous row: 6997 - 6996,"Ice Cream , Cookie Dough",37,1
#
# erroneous row: 7002 - 7001,"Granola, Homestyle, Double Chocolate Chunk",57,14
#
# erroneous row: 7003 - 7002,"Chicken, Broccoli & Cheddar Frozen Sandwiches",38,1
#
# erroneous row: 7006 - 7005,"Muffin Mix, Strawberry Cheesecake",61,19
#
# erroneous row: 7016 - 7015,"Breadsticks, Traditional",78,19
#
# erroneous row: 7019 - 7018,"Pasta Sauce, Vodka Sauce",9,9
#
# erroneous row: 7027 - 7026,"Sparkling Mineral Water, Natural Lemon Flavor",115,7
#
# erroneous row: 7052 - 7051,"Happy Tot Banana, Peach, Prune & Coconut Organic Superfoods",92,18
#
# erroneous row: 7063 - 7062,"Seasoning, Blackened",104,13
#
# erroneous row: 7065 - 7064,"IPA, Black, Back In Black",27,5
#
# erroneous row: 7066 - 7065,"Pickles, Whole, Sweet",110,13
#
# erroneous row: 7068 - 7067,"Juice, Watermelon + Peach, Comfort",31,7
#
# erroneous row: 7075 - 7074,"Bread, Gluten-Free, Multi-Grain, Deli Slice",112,3
#
# erroneous row: 7102 - 7101,"Low Calorie, Sugar Free Breakfast Syrup",29,13
#
# erroneous row: 7128 - 7127,"Truffles, Organic, Kickin' Cayenne",45,19
#
# erroneous row: 7136 - 7135,"Cream Of Chicken, Family Size",69,15
#
# erroneous row: 7137 - 7136,"Herbal Laxative, Tabs",70,11
#
# erroneous row: 7139 - 7138,"Smokehouse Sugar Free Barbeque Sauce Maple Brown, Gluten Free",5,13
#
# erroneous row: 7146 - 7145,"Toothbrush Sanitizer, Snap-On, Fresh Mint Aroma",20,11
#
# erroneous row: 7188 - 7187,"Original Chai Latte, Canister",94,7
#
# erroneous row: 7214 - 7213,"Free & Clear Laundry Detergent, 3x Concentrated, HE",75,17
#
# erroneous row: 7231 - 7230,"Ramen Noodle Soup, Beef Flavor, Family Pack",4,9
#
# erroneous row: 7269 - 7268,"Mac & Cheese, with Roasted Poblanos and Chicken",38,1
#
# erroneous row: 7281 - 7280,"Plantain Chips, Sweet",107,19
#
# erroneous row: 7289 - 7288,"Storage Container, White lid",100,21
#
# erroneous row: 7290 - 7289,"Invisible Dry Antiperspirant/Deodorant, Shower Fresh",80,11
#
# erroneous row: 7294 - 7293,"Tea Sachets, Assam",94,7
#
# erroneous row: 7295 - 7294,"SportsDrink, Orange Flavored",98,7
#
# erroneous row: 7323 - 7322,"Stain Remover & Color Booster, Lavender",75,17
#
# erroneous row: 7330 - 7329,"Almondmilk, Reduced Sugar, Original",84,16
#
# erroneous row: 7337 - 7336,"Wine Glasses, Plastic, Clear, 12 oz",111,17
#
# erroneous row: 7350 - 7349,"Bread, Sliced, Extra Sourdough",112,3
#
# erroneous row: 7354 - 7353,"Dill, Sea Salt & Olive Oil Crackers",78,19
#
# erroneous row: 7361 - 7360,"Jalapenos, Nacho Sliced",30,6
#
# erroneous row: 7381 - 7380,"Chicken Sausage, Smoked, Pineapple & Bacon",106,12
#
# erroneous row: 7389 - 7388,"Salsa, Roja, Hot",67,20
#
# erroneous row: 7407 - 7406,"Club Minis Crackers, Original",78,19
#
# erroneous row: 7409 - 7408,"Black Olives, Organic, Pitted",110,13
#
# erroneous row: 7423 - 7422,"Black Tea, Invigorating, Organic Peach",31,7
#
# erroneous row: 7445 - 7444,"Automatic Dish Powder, Grapefruit Seed & Orange Peel Extract",74,17
#
# erroneous row: 7455 - 7454,"Proactive Health Food With Hairball Care, Cat Food",41,8
#
# erroneous row: 7472 - 7471,"Pickles, Okra, Crisp, Hot",110,13
#
# erroneous row: 7487 - 7486,"Probiotic Drink, Plain",31,7
#
# erroneous row: 7521 - 7520,"Tempeh, Organic, Soy Cake",14,20
#
# erroneous row: 7524 - 7523,"Holiday Tea Trio- Dream by the Fire, Comfort and Joy, & Peppermint Bark",94,7
#
# erroneous row: 7528 - 7527,"Pasta Sauce, Classic Marinara",9,9
#
# erroneous row: 7545 - 7544,"CheeseCrisps, Cheddar & Asiago",78,19
#
# erroneous row: 7595 - 7594,"Pro-Health Toothbrush, Medium",20,11
#
# erroneous row: 7606 - 7605,"Honey Wheat Flatbread Bacon, Egg & Cheese Sandwiches",52,1
#
# erroneous row: 7628 - 7627,"Tomatoes, Snack",123,4
#
# erroneous row: 7629 - 7628,"Dressing, Jersey Sweet Onion, Calorie Free",83,4
#
# erroneous row: 7636 - 7635,"Whole Food Calcium, Magnesium & Potassium Vegetarian Tablets",47,11
#
# erroneous row: 7661 - 7660,"Pull 'n' Peel Candy, Cherry",45,19
#
# erroneous row: 7680 - 7679,"Curry Powder, Hot",76,6
#
# erroneous row: 7682 - 7681,"Master Brew Kombucha, Tart Cherry",31,7
#
# erroneous row: 7685 - 7684,"Permanent Hair Color, Dark Blonde 6N",22,11
#
# erroneous row: 7686 - 7685,"Roasted Garlic, Basil & Parsley Cultured Butter",36,16
#
# erroneous row: 7704 - 7703,"Chana Masala, Hot Spicy",76,6
#
# erroneous row: 7707 - 7706,"Lamb & Rice Prime Cuts in Gravy Tender, Meaty Bites Wet Dog Food",40,8
#
# erroneous row: 7710 - 7709,"GemWraps, Carrot",128,3
#
# erroneous row: 7718 - 7717,"Red Wine, Dark, California, 2013",28,5
#
# erroneous row: 7789 - 7788,"Deli Fresh Smoked Ham, 97% Fat Free, Gluten Free",96,20
#
# erroneous row: 7803 - 7802,"Sunscreen, Natural, Everyday, Broad Spectrum SPF 30",25,11
#
# erroneous row: 7820 - 7819,"Artichoke Hearts, Quartered",81,15
#
# erroneous row: 7835 - 7834,"Extra Strength 750, Assorted Fruit Antacid",70,11
#
# erroneous row: 7880 - 7879,"American Cheese, Pre-Sliced",2,16
#
# erroneous row: 7902 - 7901,"Ice Pops Sugar Free, Orange, Cherry, Grape",37,1
#
# erroneous row: 7904 - 7903,"Pearl Tampax Pearl Plastic Super Plus Absorbency, Unscented Tampons 18 Count Feminine Care",126,11
#
# erroneous row: 7940 - 7939,"Honey, Pure Raw Organic, Killer Bee",29,13
#
# erroneous row: 7959 - 7958,"Diet Creamy Root Beer Premium Soda, Zero Calories, Sugar Free, No Caffeine",77,7
#
# erroneous row: 7966 - 7965,"Fish, Chicken & Liver Dinner Cat Food",41,8
#
# erroneous row: 7980 - 7979,"Organic 3rd Foods Bananas, Raspberries & Vanilla with Yogurt Baby Food Organic Purees Fruit with Yogurt",92,18
#
# erroneous row: 7989 - 7988,"Crisp Okra Pickles, Mild",110,13
#
# erroneous row: 8060 - 8059,"Peanut Butter, Old Fashioned, Unsalted, Smooth",88,13
#
# erroneous row: 8096 - 8095,"White Wine Salami, Pinot Grigio",96,20
#
# erroneous row: 8100 - 8099,"Almonds Sea Salt & Vinegar, Kettle Roasted & Seasoned",117,19
#
# erroneous row: 8103 - 8102,"Naty Diapers Size 1, 8-14 lbs",56,18
#
# erroneous row: 8138 - 8137,"Face Wash, Original",109,11
#
# erroneous row: 8148 - 8147,"Syrup, Wild Maine Blueberry",29,13
#
# erroneous row: 8179 - 8178,"Kasha, 100% Pure Roasted Whole Grain Buckwheat",33,6
#
# erroneous row: 8187 - 8186,"Baby Food Pouch - Butternut Squash, Carrot & Chickpea",92,18
#
# erroneous row: 8206 - 8205,"100% Juice, Pear Nectar",98,7
#
# erroneous row: 8211 - 8210,"HE Turbo Powder Laundry Detergent Original 30 Loads, 42 Oz Laundry",75,17
#
# erroneous row: 8214 - 8213,"Concentrated Bleach, Regular Scent",75,17
#
# erroneous row: 8220 - 8219,"Aromafier Diffuser, Grey",101,17
#
# erroneous row: 8242 - 8241,"Hard Candies, Sugar Free, Caramel Apple",45,19
#
# erroneous row: 8262 - 8261,"Olive Oil, Parmesan & Roasted Garlic Oven Reds",129,1
#
# erroneous row: 8265 - 8264,"Orange Juice, California",98,7
#
# erroneous row: 8273 - 8272,"Refried Beans, with Jalapenos",59,15
#
# erroneous row: 8295 - 8294,"Juice Blend, Organic Vegetable, Beets",31,7
#
# erroneous row: 8326 - 8325,"1,000 mg Vitamin C Effervescent Powder Drink Cranberry Each Pak single",98,7
#
# erroneous row: 8342 - 8341,"Antibacterial Hand Wipes, Fresh Scent",54,17
#
# erroneous row: 8345 - 8344,"A golden crust surrounding pieces of all white meat chicken, peas, carrots, celery and onions, in a gravy made with real cream White Meat Chicken Pot Pie",38,1
#
# erroneous row: 8384 - 8383,"Just Spinach, Zucchini & Peas Stage 2 Baby Food",92,18
#
# erroneous row: 8387 - 8386,"4X Ultra Concentrated Natural Laundry Detergent, Geranium Blossoms & Vanilla",75,17
#
# erroneous row: 8400 - 8399,"Core Grain Free Turkey, Chicken Liver & Turkey Liver Natural Canned Dog Food",40,8
#
# erroneous row: 8418 - 8417,"Unscented Sport Broad Spectrum SPF 35, All Season Face Stick",118,11
#
# erroneous row: 8420 - 8419,"Dish Soap, Pink Grapefruit",74,17
#
# erroneous row: 8428 - 8427,"Coffee, Ground, Medium, Kona Blend",26,7
#
# erroneous row: 8430 - 8429,"Oysters, Smoked, Fancy, in Cottonseed Oil",95,15
#
# erroneous row: 8451 - 8450,"Granola, Organic, Seriously Seedy",57,14
#
# erroneous row: 8455 - 8454,"Fruit & Veggie Strip, Wildberry Apple",50,19
#
# erroneous row: 8459 - 8458,"Gelato Dessert, Ciaculli Tangerine",37,1
#
# erroneous row: 8467 - 8466,"Dressing, Herb, Fat Free, Tuscany",89,13
#
# erroneous row: 8479 - 8478,"Tortilla Chips, Clasico, Bacon Habanero",107,19
#
# erroneous row: 8501 - 8500,"Bonito Flakes, Aged and Dried",66,6
#
# erroneous row: 8559 - 8558,"Cottage Cheese, Natural Small Curd, 4% Milkfat Min",108,16
#
# erroneous row: 8567 - 8566,"Almond Butter, Smooth/Unsalted",88,13
#
# erroneous row: 8569 - 8568,"Rice, Jasmine, Organic Brown",63,9
#
# erroneous row: 8584 - 8583,"Plus Febreze Sport Active Fresh Scent Liquid Laundry Detergent, 46 oz, 24 loads Laundry",75,17
#
# erroneous row: 8593 - 8592,"Kale, Apple, Ginger, Romaine, Spinach, Cucumber, Celery, Parsley, Lemon Cold Pressed Juice Beverage",31,7
#
# erroneous row: 8606 - 8605,"Kale, Tuscan Herbs and Potatoes",107,19
#
# erroneous row: 8612 - 8611,"Dual Action Moisturizer, Oil-Free",73,11
#
# erroneous row: 8619 - 8618,"Lager, Premium",27,5
#
# erroneous row: 8623 - 8622,"Coffee, Organic, Instant",26,7
#
# erroneous row: 8624 - 8623,"Pasta Sauce, Authentic, Vodka Sauce",9,9
#
# erroneous row: 8625 - 8624,"Coenzyme B-Complex Capsules, Bottle",47,11
#
# erroneous row: 8629 - 8628,"Unsweetened Flax, Rice, Hemp Milk",84,16
#
# erroneous row: 8644 - 8643,"Grown-Up Soda, Extra Dry Ginger Ale",77,7
#
# erroneous row: 8705 - 8704,"Dinner Napkins, True Blue, 2-Ply",54,17
#
# erroneous row: 8728 - 8727,"Peperoncini, Greek, Sliced Golden",110,13
#
# erroneous row: 8743 - 8742,"Digestive Wheat Biscuits, Milk Chocolate Flavor",61,19
#
# erroneous row: 8747 - 8746,"Olive Oil Canyon Cut, Sea Salt & Cracked Pepper Potato Chips",107,19
#
# erroneous row: 8753 - 8752,"Medicated Arm, Neck & Leg Patch",133,11
#
# erroneous row: 8754 - 8753,"Life Scents Multilayered Fragrance Spring Edition Scented Oil Refill, Turquoise Oasis",101,17
#
# erroneous row: 8756 - 8755,"Organic Candy Drops, Assorted",45,19
#
# erroneous row: 8772 - 8771,"Charcoal Lighter Fluid, Odorless",87,17
#
# erroneous row: 8788 - 8787,"Seaweed, Roasted",66,6
#
# erroneous row: 8814 - 8813,"Sensitive Skin Stain Remover & Color Booster, 24 Loads",75,17
#
# erroneous row: 8820 - 8819,"Stella Rosso, Semi-Sweet",28,5
#
# erroneous row: 8831 - 8830,"Sweet Peas, Greens & Brown Rice Organic Baby Food",92,18
#
# erroneous row: 8834 - 8833,"Smoothie Fruits, Squished, The Green One, Over 6 Months",92,18
#
# erroneous row: 8840 - 8839,"Kids Natural Calm Multivitamin, Fruity Splash Flavor",6,2
#
# erroneous row: 8841 - 8840,"Cream Sauce, Horseradish",72,13
#
# erroneous row: 8855 - 8854,"Seasoning, Italian",104,13
#
# erroneous row: 8861 - 8860,"Sweet Peppers, Organic, Fire Roasted",110,13
#
# erroneous row: 8872 - 8871,"Quinoa Puffs, Aged Cheddar",107,19
#
# erroneous row: 8875 - 8874,"Green Chickpeas Chimichurri, Coconut Butternut Squash Gluten-Free Non GMO Meal",100,21
#
# erroneous row: 8890 - 8889,"Prunes, Pitted, Bite Size, Petite",117,19
#
# erroneous row: 8913 - 8912,"Pears, Kale & Spinach Organic Baby Food",92,18
#
# erroneous row: 8922 - 8921,"Cabernet Sauvignon, North Coast, 2011",28,5
#
# erroneous row: 8948 - 8947,"Cups, Midnight Blue, 16 oz",111,17
#
# erroneous row: 8964 - 8963,"Popped Potato Snack, Crazy Hot",107,19
#
# erroneous row: 8972 - 8971,"Ravioli, Butternut Squash, Gluten-Free",12,9
#
# erroneous row: 8996 - 8995,"Oatmeal, Instant, Banana Maple with Flax",130,14
#
# erroneous row: 9053 - 9052,"Record V Natural Bristles Toothbrush, Adult Hard",20,11
#
# erroneous row: 9056 - 9055,"Farmstyle Greek Strained Yogurt Oregon Strawberry, 2% Milkfat",120,16
#
# erroneous row: 9063 - 9062,"Special K Crustless Quiche Sausage, Quinoa, Peppers, Mozzarella & Asiago",100,21
#
# erroneous row: 9087 - 9086,"Riesling, Colombia Valley, Vintage 2013",62,5
#
# erroneous row: 9088 - 9087,"L-Tyrosine, 500 mg",47,11
#
# erroneous row: 9102 - 9101,"Yogurt, Organic Icelandic, Nonfat, Vanilla",120,16
#
# erroneous row: 9114 - 9113,"Amazing Meal Raw, Plant-Based Nutritional Supplement Chocolate Infusion",65,11
#
# erroneous row: 9158 - 9157,"Macaroons, Choc, Large",61,19
#
# erroneous row: 9165 - 9164,"Multi Bran Mini Soft Wraps, 8 Count",128,3
#
# erroneous row: 9170 - 9169,"Moisture Shave, 4 in 1, Fragrance Free",55,11
#
# erroneous row: 9178 - 9177,"Friends Honey, Chocolate & Chocolate Chip Bunny Grahams Whole Grain Snacks",61,19
#
# erroneous row: 9217 - 9216,"Chicken Breast Patties, 100% All Natural, Fully Cooked & Breaded",34,1
#
# erroneous row: 9228 - 9227,"Dulse, Wild Atlantic Sea Vegetable",66,6
#
# erroneous row: 9239 - 9238,"Cooking Sauce, Spicy Arrabbiata",9,9
#
# erroneous row: 9261 - 9260,"Ginger, Pickled",66,6
#
# erroneous row: 9265 - 9264,"Turmeric Supreme, Vegetarian Liquid Phyto-Caps",47,11
#
# erroneous row: 9268 - 9267,"Muffin & Cake Mix, Almond Flour, Chocolate",17,13
#
# erroneous row: 9275 - 9274,"Blueberry, Pear, Sweet Potato, and Spinach Super Smoothie",92,18
#
# erroneous row: 9302 - 9301,"Permanent Hair Colorant, 5M Light Mahogany Chestnut",22,11
#
# erroneous row: 9307 - 9306,"Noodles, Organic, Udon, Traditional",66,6
#
# erroneous row: 9310 - 9309,"Sports Drink, Coconut Water, Berry Blue",64,7
#
# erroneous row: 9311 - 9310,"Chicken Broth Natural Goodness, 33% Less Sodium",69,15
#
# erroneous row: 9318 - 9317,"Sandwich Bars, PB&J Blueberry and Peanut Butter",3,19
#
# erroneous row: 9347 - 9346,"Organic Apple Cider Vinegar Drink, Concord Grape-Acai",98,7
#
# erroneous row: 9350 - 9349,"Meaty Ground Dinner with Chunky Beef, Bacon & Cheese Wet Dog Food",40,8
#
# erroneous row: 9380 - 9379,"Coco-Roons, Cacao Nib",45,19
#
# erroneous row: 9396 - 9395,"Fish Oil, Lemon",47,11
#
# erroneous row: 9414 - 9413,"Mix, Pizza Crust",105,13
#
# erroneous row: 9421 - 9420,"Iced Chai, Original",31,7
#
# erroneous row: 9441 - 9440,"Handsoap, Foaming, All-Natural Antibacterial, Ginger Bergamot",25,11
#
# erroneous row: 9446 - 9445,"Cookie, Sugar",61,19
#
# ...
#
# erroneous row: 46466 - 46465,"No Drip Severe Congestion Pump Mist Fast, Powerful Congestion Relief Maximum Strength Plus Menthol",11,11
#
# erroneous row: 46501 - 46500,"Bean & Rice Chips, Ranch",107,19
#
# erroneous row: 46553 - 46552,"Nutrition Bar, Dark Chocolate Crunch",3,19
#
# erroneous row: 46561 - 46560,"Low Pulp, Calcium & Vitamin D Orange Juice Beverage",31,7
#
# erroneous row: 46564 - 46563,"Bruschetta, with Italian Basil",81,15
#
# erroneous row: 46614 - 46613,"Gain Scent Dishwasher Detergent, ActionPacs",74,17
#
# erroneous row: 46624 - 46623,"Pie Pans, Large",10,17
#
# erroneous row: 46649 - 46648,"Cookies, Family Recipe, Orange Chocolate Chip",61,19
#
# erroneous row: 46659 - 46658,"Vinegar, Red Raspberry",19,13
#
# erroneous row: 46672 - 46671,"Tofu, Soft",14,20
#
# erroneous row: 46681 - 46680,"Tall Entree Containers & Lids Containers, Tight Seal, Large Squares",85,17
#
# erroneous row: 46682 - 46681,"Organic Icelandic, Whole Milk, Vanilla Yogurt",120,16
#
# erroneous row: 46716 - 46715,"Clara Imported Beer Mazaflan, Mexico",27,5
#
# erroneous row: 46726 - 46725,"Champagne, Extra Dry, Sparkling California",134,5
#
# erroneous row: 46734 - 46733,"Crackers, Mediterranean, Rosemary Cheese",78,19
#
# erroneous row: 46735 - 46734,"For Frizzy, Dry, Unmanageable Hair Sleek & Shine Shampoo",22,11
#
# erroneous row: 46755 - 46754,"Fish Oil, Omega Swirl, Lemon Zest",47,11
#
# erroneous row: 46761 - 46760,"Corn Flour, Golden, Masa Harina",17,13
#
# erroneous row: 46764 - 46763,"Corn Chips Mexican Style, No Salt",107,19
#
# erroneous row: 46792 - 46791,"Potato Chips, Sweet Potato",107,19
#
# erroneous row: 46808 - 46807,"Bananas, Raspberries & Oats Organic Baby Food",92,18
#
# erroneous row: 46809 - 46808,"Milanoe, Bitter",124,5
#
# erroneous row: 46828 - 46827,"Extra Strength Acetaminophen, Aspirin (NSAID) and Caffeine Caplets Pain Reliever/Pain Reliever Aid",133,11
#
# erroneous row: 46837 - 46836,"Paste, Red Curry",66,6
#
# erroneous row: 46844 - 46843,"Almond And Shea Butter Moisturizing Shampoo, for Dry Damaged Hair",22,11
#
# erroneous row: 46899 - 46898,"Marinara, Indulgent, Caramelized Onion & Butter",9,9
#
# erroneous row: 46902 - 46901,"Culinary Stock, Beef Style",69,15
#
# erroneous row: 46905 - 46904,"Bread, Organic, Spelt",112,3
#
# erroneous row: 46910 - 46909,"Tortilla Chips, Organic, Ancient Grains",107,19
#
# erroneous row: 46914 - 46913,"Chao, Vegan, Tomato Cayenne, Slices",21,16
#
# erroneous row: 46939 - 46938,"Quinoa Puffs, Sea Salt Truffle",107,19
#
# erroneous row: 46958 - 46957,"Baking Flour, 1 to 1",17,13
#
# erroneous row: 46990 - 46989,"Pasta Sauce, Homestyle, Meatless, Quart Size",9,9
#
# erroneous row: 47034 - 47033,"Go Fresh Cool Moisture Body Wash, Cucumber & Green Tea Scent",127,11
#
# erroneous row: 47035 - 47034,"Fruit Spread, Strawberry",88,13
#
# erroneous row: 47042 - 47041,"Louis Jadot Chardonnay, Macon Villages",62,5
#
# erroneous row: 47050 - 47049,"Baby Food Pouch - Kale, Sweet Corn & Quinoa",92,18
#
# erroneous row: 47061 - 47060,"Sparkling Water, Cran-Raspberry",115,7
#
# erroneous row: 47096 - 47095,"Napa Valley Homemade Sauce Parmesan, Asiago & Romano",9,9
#
# erroneous row: 47123 - 47122,"Lightdays® Pantiliners, Regular",126,11
#
# erroneous row: 47136 - 47135,"Organic Echinacea Plus, Caffeine Free Herbal Tea",94,7
#
# erroneous row: 47159 - 47158,"Maxi Pads, Overnight",126,11
#
# erroneous row: 47173 - 47172,"Toy & Table Cleaner, Free & Clear, Disney Baby",82,18
#
# erroneous row: 47178 - 47177,"Smmmile, It's Three Cheesy Macaroni & Cheese Dinner",4,9
#
# erroneous row: 47202 - 47201,"Soy Station Cheddar, Jack & Mozarella Style Cheese-Alternative Shreds",21,16
#
# erroneous row: 47234 - 47233,"Bananas, Dark Chocolate",45,19
#
# erroneous row: 47240 - 47239,"Cherry, Grape, Lemon, Apple, and Orange Sugar Candy",45,19
#
# erroneous row: 47289 - 47288,"All Purpose Cleaner, Fragrance Free",114,17
#
# erroneous row: 47306 - 47305,"Green Chiles, Diced, Fire Roasted, Mild",30,6
#
# erroneous row: 47313 - 47312,"Skin Relief Body Wash, Fragrance Free",127,11
#
# erroneous row: 47314 - 47313,"Sauvignon Blanc, Napa County",62,5
#
# erroneous row: 47332 - 47331,"Pro-Health Pulsar Battery Operated Toothbrush, Medium",20,11
#
# erroneous row: 47408 - 47407,"Starter Kit, 2 in 1, Sweeping & Mopping",114,17
#
# erroneous row: 47426 - 47425,"Pink Moscato Champagne, Sparkling, California",134,5
#
# erroneous row: 47442 - 47441,"Extra Dry Ginger Ale, Lightly Sweetened",77,7
#
# erroneous row: 47443 - 47442,"Cocktail Mixer, Mojito",6,2
#
# erroneous row: 47488 - 47487,"Chili Beans, White,  Premium",59,15
#
# erroneous row: 47491 - 47490,"Soy Sauce, Premium",66,6
#
# erroneous row: 47494 - 47493,"Granola, Super Seed & Fruit",57,14
#
# erroneous row: 47508 - 47507,"Stage 2 Pear, Zucchini, Peas Baby Food",92,18
#
# erroneous row: 47535 - 47534,"In a creamy sauce, topped with aged parmesan cheese Mushroom & Spring Pea Risotto",38,1
#
# erroneous row: 47555 - 47554,"Mocha Latte & Dark Chocolate Swirl, Silky Smooth",45,19
#
# erroneous row: 47587 - 47586,"Limited Edition Entree, Chicken Tiki Masala",100,21
#
# erroneous row: 47607 - 47606,"3rd Foods Carrots Peas & Corn with Li'L Bits, Crawler",92,18
#
# erroneous row: 47611 - 47610,"Pretzel Sticks, Gluten Free",107,19
#
# erroneous row: 47646 - 47645,"Seitan, Traditional, Strips",65,11
#
# erroneous row: 47671 - 47670,"Vaginal Antifungal, 3-Day Treatment Ovules, Combination Pack",126,11
#
# erroneous row: 47699 - 47698,"Salisbury Steak Meal  with Gravy, Mashed Potatoes & Corn",38,1
#
# erroneous row: 47701 - 47700,"Mouthwash, Antigingivitis/Antiplaque, Alcohol Free, Spearmint Surge",20,11
#
# erroneous row: 47721 - 47720,"Honey, Pure",29,13
#
# erroneous row: 47730 - 47729,"Salami, Rose, Recipe No. 7",96,20
#
# erroneous row: 47734 - 47733,"Intense i-Color Eye liner - For Hazel Eyes, Black Pearl",132,11
#
# erroneous row: 47747 - 47746,"Raw Shea Butter Bath, Body and Massage Oil",6,2
#
# erroneous row: 47774 - 47773,"Lay's Potato Chips Kettle Cooked, Lattice Cut Sea Salt",107,19
#
# erroneous row: 47776 - 47775,"Concentrated Butcher's Bone Broth, Chicken",100,21
#
# erroneous row: 47786 - 47785,"Aged Swiss Cheese, Sliced",21,16
#
# erroneous row: 47806 - 47805,"Vinegar, Apple Cider",19,13
#
# erroneous row: 47811 - 47810,"Penne Rigate, 100% Whole Wheat",131,9
#
# erroneous row: 47821 - 47820,"Pizza, Naan, Artisan Crust, Spinach & Paneer Cheese",79,1
#
# erroneous row: 47822 - 47821,"Yams, Cut Sweet Potatoes in Syrup",81,15
#
# erroneous row: 47830 - 47829,"Horseradish, Cream, Hot",72,13
#
# erroneous row: 47865 - 47864,"Coconut Butter, Dark Chocolate Fudge",88,13
#
# erroneous row: 47871 - 47870,"Toilet Bowl Cleaner w/ Bleach, Fresh Scent",114,17
#
# erroneous row: 47899 - 47898,"Milk, 1% Lowfat",84,16
#
# erroneous row: 47901 - 47900,"Uncured, No Sugar, Hickory Smoked Bacon",106,12
#
# erroneous row: 47953 - 47952,"Soap, Buttermilk",102,18
#
# erroneous row: 47998 - 47997,"Bread, Butter Top Wheat",112,3
#
# erroneous row: 48000 - 47999,"Chili Mixin's, Six Gun, Original",30,6
#
# erroneous row: 48020 - 48019,"Coconut Water, with Pineapple",31,7
#
# erroneous row: 48037 - 48036,"Clover Honey, US Grade A",29,13
#
# erroneous row: 48045 - 48044,"Noodles, Udon, Japanese",66,6
#
# erroneous row: 48046 - 48045,"Gummi Candy, Fizzy Cola",45,19
#
# erroneous row: 48047 - 48046,"Pudding & Pie Filling, Instant, Reduced Calorie, Vanilla",105,13
#
# erroneous row: 48048 - 48047,"Carrot, Apple & Mango Organic",92,18
#
# erroneous row: 48049 - 48048,"Antibiotic Free, Hormone Free, Vegetarian Fed, Fearless Beef Franks",106,12
#
# erroneous row: 48058 - 48057,"Hummus, Hope, Original Recipe",67,20
#
# erroneous row: 48064 - 48063,"Bagels, Sliced, Cinnamon Raisin",93,3
#
# erroneous row: 48076 - 48075,"Ice Cream, Super Premium, Coffee",37,1
#
# erroneous row: 48096 - 48095,"Purified Water, 9.5pH+",115,7
#
# erroneous row: 48110 - 48109,"Tortilla Chips, Clasico, Jalapeno Lime",107,19
#
# erroneous row: 48112 - 48111,"Organic Baby Food Sweet Potato Apple, Grape & Spinach 2",92,18
#
# erroneous row: 48126 - 48125,"Collard Greens, Lower Sodium",81,15
#
# erroneous row: 48134 - 48133,"Organic Baby Food, Sweet Potatoes Starting Solids 1",92,18
#
# erroneous row: 48189 - 48188,"Body Scrub, and Shower Gel, Citrus",25,11
#
# erroneous row: 48229 - 48228,"360 Whole Mouth Clean Full Head Toothbrush, Medium",20,11
#
# erroneous row: 48268 - 48267,"Hydrating Serum, Ultra Hyaluronic, Dry",109,11
#
# erroneous row: 48277 - 48276,"Natural Lavender Mint Creme Filled Dark Chocolate, 72% Cocoa",45,19
#
# erroneous row: 48280 - 48279,"Blue 1000 mg Vitamin C Fizzy Drink Mix, Triple Berry",47,11
#
# erroneous row: 48303 - 48302,"PODS Plus Febreze Odor Defense Laundry Detergent Pacs, Active Fresh Scent, 32 count, Designed For Regular and HE Washers Laundry",75,17
#
# erroneous row: 48321 - 48320,"PODS Laundry Detergent, Original Designed for Regular and HE Washers Laundry",75,17
#
# erroneous row: 48323 - 48322,"Natural Toothpaste, Whitening Gel",20,11
#
# erroneous row: 48330 - 48329,"Dietary Supplement, Digest Gold, Capsules, Bottle",70,11
#
# erroneous row: 48353 - 48352,"Vegan Meatballs, Zesty Italian",38,1
#
# erroneous row: 48357 - 48356,"Muffins, Flax, Cranberry Orange",93,3
#
# erroneous row: 48366 - 48365,"Diced Tomatoes with Onion, Celery & Bell Peppers",81,15
#
# erroneous row: 48403 - 48402,"Homeopathic Remedy, for Travel Fatigue",6,2
#
# erroneous row: 48407 - 48406,"Bread, Gluten-Free, Super Seeded Multi-Grain",112,3
#
# erroneous row: 48411 - 48410,"Water, Sparkling, Sparkling Lime",115,7
#
# erroneous row: 48419 - 48418,"Cherries, Maraschino, Pitted",99,15
#
# erroneous row: 48426 - 48425,"Muffin & Quick Bread Mix, Premium, Cinnabon Cinnamon Streusel",105,13
#
# erroneous row: 48429 - 48428,"Corn Snack, Mini, Fuego",107,19
#
# erroneous row: 48431 - 48430,"Split Pea Soup, Sicilian, Spaccarelli",69,15
#
# erroneous row: 48443 - 48442,"Broccoli, Kale & Cheddar Cheese Organic Veggie Snack",92,18
#
# erroneous row: 48445 - 48444,"Tofu, Medium Firm (Regular)",14,20
#
# erroneous row: 48454 - 48453,"Water, Unsweet, Crisp Apple",115,7
#
# erroneous row: 48458 - 48457,"Diet Black Cherry Premium Soda, Zero Calories, Sugar Free, No Caffeine",77,7
#
# erroneous row: 48471 - 48470,"Heavy Duty Freezer Bags, Quart, Double Zipper",85,17
#
# erroneous row: 48472 - 48471,"Cotton Balls, Regular Size",73,11
#
# erroneous row: 48492 - 48491,"Tofu, Extra Firm",14,20
#
# erroneous row: 48510 - 48509,"Sport Tampons, Super Absorbency, Unscented",126,11
#
# erroneous row: 48543 - 48542,"Minis, Assorted Ice Cream Bars",37,1
#
# erroneous row: 48573 - 48572,"Chili Peppers, Hot",110,13
#
# erroneous row: 48586 - 48585,"Lasagna, Whole Wheat",131,9
#
# erroneous row: 48590 - 48589,"Organic Baby Food Carrot, Sweet Potato & Brown Rice Stage 2",92,18
#
# erroneous row: 48591 - 48590,"Laxative Powder Solution, Unflavored",70,11
#
# erroneous row: 48593 - 48592,"Organic Yogurt, Vanilla",120,16
#
# erroneous row: 48600 - 48599,"Mediterranean Style Chicken, Rigatoni & Broccooli",38,1
#
# erroneous row: 48623 - 48622,"Condensed Milk, Sweetened, Full Cream",17,13
#
# erroneous row: 48638 - 48637,"Green Supreme Apple, Kale & Lemon Cold Pressured Fruit & Vegetable Juice",31,7
#
# erroneous row: 48644 - 48643,"Peanuts, Caramel & Nougat In Rice Milk Chocolatey Coating Candy Bar",45,19
#
# erroneous row: 48651 - 48650,"Regular Premium Pork Sausage, Roll",34,1
#
# erroneous row: 48652 - 48651,"Toner & Freshner, Complexion, Aloe Vera, Dry/Sensitive Skin",109,11
#
# erroneous row: 48655 - 48654,"Calcium Citrate, Food-Based, Mini-Tabs",47,11
#
# erroneous row: 48672 - 48671,"Steamfresh Chef's Favorites Broccoli, Cauliflower, Carrots with Cheese Sauce",100,21
#
# erroneous row: 48677 - 48676,"Bean & Rice Chips, Nacho",107,19
#
# erroneous row: 48681 - 48680,"Ham, Cheddar & Mini Ritz Snack Duos",13,20
#
# erroneous row: 48711 - 48710,"Pinto Noir, Monterey, 2007",28,5
#
# erroneous row: 48716 - 48715,"Organic Honeybush Tea, Caffeine Free",94,7
#
# erroneous row: 48730 - 48729,"Juice, Organic, Acai with Pomegranate",31,7
#
# erroneous row: 48758 - 48757,"Salt, Organic, Season",104,13
#
# erroneous row: 48773 - 48772,"Dark Chocolate, Intense Mint",45,19
#
# erroneous row: 48779 - 48778,"Fit Super A Juice, Cold Pressed, Carrot/Apple/Ginger",18,10
#
# erroneous row: 48786 - 48785,"Power Blend Superfood Brussels Sprouts, Napa Cabbage, Kohlrabi, Broccoli, Carrots & Kale",123,4
#
# erroneous row: 48792 - 48791,"Creamy Coconut Organic Dark Chocolate, 57% Cocoa",45,19
#
# erroneous row: 48800 - 48799,"Fish Sticks, Classic Crunchy",129,1
#
# erroneous row: 48845 - 48844,"Yogurt Cheese, Spreadable, Mediterranean Style, Lite",108,16
#
# erroneous row: 48860 - 48859,"Bread, Natural Pumpernickel",112,3
#
# erroneous row: 48900 - 48899,"Frankincense, 100% Pure, Essential Oils",101,17
#
# erroneous row: 48920 - 48919,"Cakes, Chocolate Chip",61,19
#
# erroneous row: 48952 - 48951,"Yogurt, Greek, Nonfat, Strained, Blended with Vanilla",120,16
#
# erroneous row: 48981 - 48980,"Satay Sauce, Thai Peanut, Spicy-Hot",66,6
#
# erroneous row: 48986 - 48985,"Artichoke Hearts, Quartered Marinated",81,15
#
# erroneous row: 48987 - 48986,"Herbal Laxative Tabs, Tablets",70,11
#
# erroneous row: 48993 - 48992,"Iso Maki, Seaweed Wrapped Rice Cracker",66,6
#
# erroneous row: 48995 - 48994,"Fruit Spread, Deluxe, Fancy Plum",88,13
#
# erroneous row: 49017 - 49016,"Frozen Pie, Ready to Bake, Marionberry",119,1
#
# erroneous row: 49032 - 49031,"Ale, Hop Stoopid",27,5
#
# erroneous row: 49045 - 49044,"Organic Pears, Peas and Broccoli Puree Stage 1",92,18
#
# erroneous row: 49069 - 49068,"P3 Brown Sugar Ham, Cheddar Cheese & Peanut Almond Nut Clusters",13,20
#
# erroneous row: 49081 - 49080,"Coconut Milk Non Dairy Frozen Dessert, Pomegranate Chip",37,1
#
# erroneous row: 49087 - 49086,"Coconut Bliss Frozen Dessert, Dark Chocolate",37,1
#
# erroneous row: 49102 - 49101,"Dog Treats, Lamb Formula",40,8
#
# erroneous row: 49136 - 49135,"Cereal, Superfood, Acai Blueberry",121,14
#
# erroneous row: 49144 - 49143,"Fruit Roll, Mango Flavor",50,19
#
# erroneous row: 49147 - 49146,"Whole Grain Pilaf with Brown Rice, Quinoa, Kale, Artichokes & Zucchini",129,1
#
# erroneous row: 49166 - 49165,"Gelpacs, Orange Scent",74,17
#
# erroneous row: 49188 - 49187,"Sesame Oil, Refined",19,13
#
# erroneous row: 49197 - 49196,"Anti-Fungal Liquid, Maximum Strength",6,2
#
# erroneous row: 49202 - 49201,"Banana, Peach and Mango Fruit Pouch",92,18
#
# erroneous row: 49210 - 49209,"Crackers, Original, Stoned Wheat",61,19
#
# erroneous row: 49231 - 49230,"Seaweed Snack, Premium Roasted, Spicy Chipotle",78,19
#
# erroneous row: 49252 - 49251,"Foaming Hand Wash, Rosemary - Mint",127,11
#
# erroneous row: 49264 - 49263,"Perfect Lavender Laundry Detergent, HE",75,17
#
# erroneous row: 49267 - 49266,"All Natural Family Size Olilve Oil, Rosemary & Garlic Oven Fries",129,1
#
# erroneous row: 49293 - 49292,"Red Wine, Crianza, 2009",28,5
#
# erroneous row: 49389 - 49388,"Foot Cream, Healing, Aloe",127,11
#
# erroneous row: 49401 - 49400,"Pumpkin Seeds, Heirloom, Organic, With a Bit of Sea Salt",117,19
#
# erroneous row: 49402 - 49401,"Chicken Base, Organic",69,15
#
# erroneous row: 49405 - 49404,"Fruity Bears, Organic",50,19
#
# erroneous row: 49406 - 49405,"Liquid Muscle Gel Multipurpose Cleaner, Crisp Lemon",114,17
#
# erroneous row: 49419 - 49418,"Sushinori, Roasted",66,6
#
# erroneous row: 49422 - 49421,"Salame, Peppered",106,12
#
# erroneous row: 49432 - 49431,"Pretzels, Mighty Minis",107,19
#
# erroneous row: 49438 - 49437,"Asian Sauces, Gourmet, Thai Peanut",66,6
#
# erroneous row: 49458 - 49457,"Crawfish, Shrimp & Crab Boil in Bag",104,13
#
# erroneous row: 49461 - 49460,"Disinfectant Max Cover Mist, Lavender Fields",114,17
#
# erroneous row: 49511 - 49510,"Lentil Chips, Aged White Cheddar",107,19
#
# erroneous row: 49566 - 49565,"Batteries, Lithium, AA",87,17
#
# erroneous row: 49591 - 49590,"Good Budddy, Jerky Strips, Real Chicken Recipe",40,8
#
# erroneous row: 49609 - 49608,"Certified Organic Spanish Style Rice With Quinoa, Red Bell Peppers & Corn",4,9
#
# erroneous row: 49636 - 49635,"Baby Food Blueberry, Parsnip & Buckwheat Stage 2",83,4
#
# erroneous row: 49640 - 49639,"Pecans, Maple, Premium Blend",117,19
#
# erroneous row: 49653 - 49652,"Drain Cleaner, Fresh Citrus & Sage Fragrance",114,17
#
# erroneous row: 49655 - 49654,"Teriyaki Sauce, Sesame, Original",5,13
#
# erroneous row: 49685 - 49684,"Vodka, Triple Distilled, Twist of Vanilla",124,5

# %%
import pandas as pd

df = pd.read_csv("products.csv", dtype=str)
df = df[['product_id', 'product_name', 'aisle_id', 'department_id']]  
df.to_csv("products_cleaned.csv", index=False, quoting=1)
