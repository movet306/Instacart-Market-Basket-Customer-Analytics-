# %%
import pandas as pd
orders = pd.read_csv("orders.csv")

# %%
print(orders.info()) 
print(orders.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3421083 entries, 0 to 3421082
# Data columns (total 7 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   eval_set                object
#  3   order_number            int64
#  4   order_dow               int64
#  5   order_hour_of_day       int64
#  6   days_since_prior_order  float64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 182.7+ MB
# None
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
# ...

# %%
print(orders.duplicated().sum())
# Out:
# 0

# %%
print(orders['order_id'].is_unique)
# Out:
# True

# %%
print(orders['eval_set'].value_counts())
print(orders['order_dow'].unique())
print(orders['order_hour_of_day'].unique())
# Out:
# eval_set
# prior    3214874
# train     131209
# test       75000
# Name: count, dtype: int64
# [2 3 4 1 5 0 6]
# [ 8  7 12 15  9 14 16 11 10 19 18 17 13 20  0 21 22  5 23  4  6  1  2  3]

# %%
orders.to_csv("cleaned_orders.csv", index=False)

# %%
import pandas as pd
products= pd.read_csv("products.csv")

# %%
print(orders.info()) 
print(products.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3421083 entries, 0 to 3421082
# Data columns (total 7 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   eval_set                object
#  3   order_number            int64
#  4   order_dow               int64
#  5   order_hour_of_day       int64
#  6   days_since_prior_order  float64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 182.7+ MB
# None
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
# ...

# %%
print(products.shape)
# Out:
# (49688, 4)

# %%
print(products.isnull().sum())
# Out:
# product_id       0
# product_name     0
# aisle_id         0
# department_id    0
# dtype: int64

# %%
print(products.duplicated().sum())
# Out:
# 0

# %%
print(products['product_id'].is_unique)
# Out:
# True

# %%
print(products['aisle_id'].unique()[:10])        
print(products['department_id'].unique()[:10])
# Out:
# [ 61 104  94  38   5  11  98 116 120 115]
# [19 13  7  1 11 16 17 18 12  9]

# %%
print(products[products['product_name'].isnull() | (products['product_name'] == '')])
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, aisle_id, department_id]
# Index: []

# %%
products.to_csv("cleaned_products.csv", index=False)

# %%
prior = pd.read_csv("order_products__prior.csv") 
print(prior.info())
print(prior.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32434489 entries, 0 to 32434488
# Data columns (total 4 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   order_id           int64
#  1   product_id         int64
#  2   add_to_cart_order  int64
#  3   reordered          int64
# dtypes: int64(4)
# memory usage: 989.8 MB
# None
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
print(prior.isnull().sum())
# Out:
# order_id             0
# product_id           0
# add_to_cart_order    0
# reordered            0
# dtype: int64

# %%
print(prior.duplicated().sum())
# Out:
# 0

# %%
products = pd.read_csv("cleaned_products.csv")
orders = pd.read_csv("cleaned_orders.csv")

print(prior[~prior['product_id'].isin(products['product_id'])])
print(prior[~prior['order_id'].isin(orders['order_id'])])
# Out:
# Empty DataFrame
# Columns: [order_id, product_id, add_to_cart_order, reordered]
# Index: []
# Empty DataFrame
# Columns: [order_id, product_id, add_to_cart_order, reordered]
# Index: []

# %%
print(prior['reordered'].unique())
# Out:
# [1 0]

# %%
prior.to_csv("cleaned_order_products_prior.csv", index=False)

# %%
train = pd.read_csv("order_products__train.csv")
print(train.info())
print(train.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1384617 entries, 0 to 1384616
# Data columns (total 4 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   order_id           1384617 non-null  int64
#  1   product_id         1384617 non-null  int64
#  2   add_to_cart_order  1384617 non-null  int64
#  3   reordered          1384617 non-null  int64
# dtypes: int64(4)
# memory usage: 42.3 MB
# None
#    order_id  product_id  add_to_cart_order  reordered
# 0         1       49302                  1          1
# 1         1       11109                  2          1
# 2         1       10246                  3          0
# 3         1       49683                  4          0
# 4         1       43633                  5          1

# %%
print(train.isnull().sum())
# Out:
# order_id             0
# product_id           0
# add_to_cart_order    0
# reordered            0
# dtype: int64

# %%
print(train.duplicated().sum())
# Out:
# 0

# %%
products = pd.read_csv("cleaned_products.csv")
orders = pd.read_csv("cleaned_orders.csv")

print(train[~train['product_id'].isin(products['product_id'])])
print(train[~train['order_id'].isin(orders['order_id'])])
# Out:
# Empty DataFrame
# Columns: [order_id, product_id, add_to_cart_order, reordered]
# Index: []
# Empty DataFrame
# Columns: [order_id, product_id, add_to_cart_order, reordered]
# Index: []

# %%
print(train['reordered'].unique())
# Out:
# [1 0]

# %%
train.to_csv("cleaned_order_products_train.csv", index=False)

# %%
departments = pd.read_csv("departments.csv")
print(departments.info())
print(departments.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   department_id  21 non-null     int64
#  1   department     21 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 468.0+ bytes
# None
#    department_id department
# 0              1     frozen
# 1              2      other
# 2              3     bakery
# 3              4    produce
# 4              5    alcohol

# %%
print(departments.isnull().sum())
# Out:
# department_id    0
# department       0
# dtype: int64

# %%
print(departments.duplicated().sum())
# Out:
# 0

# %%
print(departments.duplicated().sum())
# Out:
# 0

# %%
print(departments['department_id'].is_unique)
# Out:
# True

# %%
print(departments[departments['department'].isnull() | (departments['department'] == '')])
# Out:
# Empty DataFrame
# Columns: [department_id, department]
# Index: []

# %%
departments.to_csv("cleaned_departments.csv", index=False)

# %%
aisles = pd.read_csv("aisles.csv")
print(aisles.info())
print(aisles.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   aisle_id  134 non-null    int64
#  1   aisle     134 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB
# None
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation

# %%
print(aisles.isnull().sum())
# Out:
# aisle_id    0
# aisle       0
# dtype: int64

# %%
print(aisles.duplicated().sum())
# Out:
# 0

# %%
print(aisles['aisle_id'].is_unique)
# Out:
# True

# %%
print(aisles[aisles['aisle'].isnull() | (aisles['aisle'] == '')])
# Out:
# Empty DataFrame
# Columns: [aisle_id, aisle]
# Index: []

# %%
aisles.to_csv("cleaned_aisles.csv", index=False)

# %%
import pandas as pd

df = pd.read_csv('products.csv')
print(df['product_name'].str.len().max())
print(df[df['product_name'].str.len() > 512])
# Out:
# 159
# Empty DataFrame
# Columns: [product_id, product_name, aisle_id, department_id]
# Index: []

# %%
with open('products.csv', encoding='utf-8') as f:
    for i, line in enumerate(f):
        if len(line.strip().split(',')) != 4:
            print(f"Hatalı satır: {i+1} - {line}")
# Out:
# Hatalı satır: 31 - 30,"Three Cheese Ziti, Marinara with Meatballs",38,1
#
# Hatalı satır: 49 - 48,"School Glue, Washable, No Run",87,17
#
# Hatalı satır: 68 - 67,"Jelly, Blackberry",88,13
#
# Hatalı satır: 69 - 68,"Pancake Mix, Buttermilk",130,14
#
# Hatalı satır: 76 - 75,"Hemp Protein, Organic",65,11
#
# Hatalı satır: 87 - 86,"Camilia, Single Liquid Doses",6,2
#
# Hatalı satır: 102 - 101,"Bread, Healthy Whole Grain",112,3
#
# Hatalı satır: 112 - 111,"Fabric Softener, Geranium Scent",75,17
#
# Hatalı satır: 140 - 139,"Zita Cut, No. 118",131,9
#
# Hatalı satır: 153 - 152,"3 in 1 Soap for Every Man, Cucumber & Lemon",25,11
#
# Hatalı satır: 154 - 153,"Fabric Refresher Meadows & Rain Air Freshener (1 Count, 27 oz)  Air Care",75,17
#
# Hatalı satır: 155 - 154,"Corn Dogs, Mini, Honey Crunchy Flavor",129,1
#
# Hatalı satır: 160 - 159,"Calcium Adult Gummy Vitamins, Orange Cherry & Strawberry",47,11
#
# Hatalı satır: 204 - 203,"Rescue Remedy, Spray",11,11
#
# ...

# %%
import pandas as pd

df = pd.read_csv("products.csv", dtype=str)
df = df[['product_id', 'product_name', 'aisle_id', 'department_id']]  # sadece doğru kolonlar
df.to_csv("products_cleaned.csv", index=False, quoting=1)  # quoting=1 → tüm string alanları çift tırnakla kaydeder
